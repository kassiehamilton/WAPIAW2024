# %%
import os
import pandas as pd
import scipy.stats as sci
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import MultiComparison
from statsmodels.stats.multitest import multipletests
import warnings
import glob
import sys
curr_path = os.getcwd()
sys.path.append(f"{curr_path}")

# load structural data

# structural_results_path = "/Users/hkassandra/Desktop/WAPIAW/Results/meta_analysis_with_covars.csv"

# df_structural = pd.read_csv(structural_results_path)
# df_structural['estimate'] = abs(df_structural['estimate'])

# df_volume = df_structural[(df_structural["IDP_name"].str.contains("volume")) | (df_structural["Yeo_name"] == "Subcortical")]
# df_area = df_structural[(df_structural["IDP_name"].str.contains("area")) & (df_structural["Yeo_name"] != "Subcortical")]
# df_thickness = df_structural[(df_structural["IDP_name"].str.contains("thickness")) & (df_structural["Yeo_name"] != "Subcortical")]

df_volume = pd.read_csv("Results/meta_results_volume/meta_analysis_without_covars.csv")
df_area = pd.read_csv("Results/meta_results_area/meta_analysis_without_covars.csv")
df_thickness = pd.read_csv("Results/meta_results_thickness/meta_analysis_without_covars.csv")

structural_dfs = [df_volume, df_area, df_thickness]

# load functional data

schaefer_partial_path = "Results/schaefer_partials/meta_analysis_without_covars_with_yeo.csv"
schaefer_partial_df = pd.read_csv(schaefer_partial_path)
schaefer_full_path = "Results/schaefer_full/meta_analysis_without_covars_with_yeo.csv"
schaefer_full_df = pd.read_csv(schaefer_full_path) 

functional_dfs = [schaefer_partial_df, schaefer_full_df]

df_volume["estimate"] = df_volume["estimate"].abs()
df_volume["imaging_metric"] = "Gray Matter Volume"
df_area["estimate"] = df_area["estimate"].abs()
df_area["imaging_metric"] = "Cortical Surface Area" 
df_thickness["estimate"] = df_thickness["estimate"].abs()
df_thickness["imaging_metric"] = "Cortical Thickness"
schaefer_partial_df["estimate"] = schaefer_partial_df["estimate"].abs()
schaefer_partial_df["imaging_metric"] = "Partial Netmats (Schaefer)"
schaefer_full_df["estimate"] = schaefer_full_df["estimate"].abs()
schaefer_full_df["imaging_metric"] = "Full Netmats (Schaefer)"

yeo_mapping = {
    1: "Visual",
    2: "Somatomotor",
    3: "Dorsal Attention",
    4: "Ventral Attention",
    5: "Limbic",
    6: "Frontoparietal",
    7: "Default",
    8: "Subcortical"
}
schaefer_partial_df['Yeo'] = schaefer_partial_df['Yeo1']
schaefer_partial_df['Yeo_name'] = schaefer_partial_df['Yeo1'].map(yeo_mapping)
schaefer_full_df['Yeo'] = schaefer_full_df['Yeo1']
schaefer_full_df['Yeo_name'] = schaefer_full_df['Yeo1'].map(yeo_mapping)

df_total = pd.concat([df_volume, df_area, df_thickness, schaefer_partial_df, schaefer_full_df], ignore_index=True)

print(df_total.head())

print(schaefer_partial_df.columns)
print(schaefer_partial_df["phen_group"].unique())
print(max(schaefer_partial_df["estimate"]))

all_dfs = structural_dfs + functional_dfs
# Out:
#         name  estimate        se   z-score   p-value  ci_0.025  ci_0.975  \
# 0  intercept  0.008897  0.007243 -1.228264  0.219348 -0.023093  0.005300
# 1  intercept  0.019102  0.008982 -2.126764  0.033440 -0.036707 -0.001498
# 2  intercept  0.024409  0.011987 -2.036239  0.041726 -0.047904 -0.000914
# 3  intercept  0.012874  0.016129 -0.798223  0.424741 -0.044486  0.018737
# 4  intercept  0.017651  0.007091 -2.489250  0.012801 -0.031549 -0.003753
#
#                    IDP_name   phen_group  Yeo Yeo_name     p_fdr  \
# 0           rhlingualvolume  Neuroticism  1.0   Visual  0.322814
# 1   rhparahippocampalvolume  Neuroticism  1.0   Visual  0.072453
# 2          rhfusiformvolume  Neuroticism  1.0   Visual  0.083453
# 3  rhlateraloccipitalvolume  Neuroticism  1.0   Visual  0.534352
# 4     rhpericalcarinevolume  Neuroticism  1.0   Visual  0.034431
#
#    Significance      imaging_metric  Unnamed: 0  Node1  Node2  Yeo1  Yeo2
# 0         False  Gray Matter Volume         NaN    NaN    NaN   NaN   NaN
# 1         False  Gray Matter Volume         NaN    NaN    NaN   NaN   NaN
# 2         False  Gray Matter Volume         NaN    NaN    NaN   NaN   NaN
# 3         False  Gray Matter Volume         NaN    NaN    NaN   NaN   NaN
# 4          True  Gray Matter Volume         NaN    NaN    NaN   NaN   NaN
# Index(['Unnamed: 0', 'name', 'estimate', 'se', 'z-score', 'p-value',
#        'ci_0.025', 'ci_0.975', 'IDP_name', 'phen_group', 'p_fdr',
#        'Significance', 'Node1', 'Node2', 'Yeo1', 'Yeo2', 'imaging_metric',
#        'Yeo', 'Yeo_name'],
#       dtype='object')
# ['Neuroticism' 'Depression']
# 0.0459068147616787

# %%
### PHENO --> 6X main effect of depression phenotype (with FDR correction) 

# List to store p-values and imaging metrics from ANOVA tests
all_img_metrics = []
p_values = []

# First loop: Collect p-values
for df in all_dfs:
    model = ols("""estimate ~ C(phen_group)""", data=df).fit()
    anova_results = sm.stats.anova_lm(model, typ=2)
    img_met = df["imaging_metric"].unique()[0]
    all_img_metrics.append(img_met)

    # Extract the p-value from the ANOVA results
    p_value = anova_results['PR(>F)'][0]
    p_values.append(p_value)

    # Post hoc for Yeo_name
    mc = MultiComparison(df['estimate'], df['phen_group'])
    posthoc_results = mc.tukeyhsd()

# Apply FDR correction to the collected p-values
_, corrected_p_values, _, _ = multipletests(p_values, alpha=0.05, method='fdr_bh')

# Second loop: Append FDR-corrected p-values to the ANOVA results and print
corrected_p_index = 0
for df in all_dfs:
    model = ols("""estimate ~ C(phen_group)""", data=df).fit()
    anova_results = sm.stats.anova_lm(model, typ=2)
    img_met = df["imaging_metric"].unique()[0]

    # Add a new column for FDR corrected p-values
    anova_results['P_FDR'] = [corrected_p_values[corrected_p_index]] + [None] * (len(anova_results) - 1)
    corrected_p_index += 1

    # Print the anova_results with the new column
    print(f"\n\n One-Way ANOVA with depression phenotype group on {img_met} results - with FDR correction \n\n")
    print(anova_results)

    # Post hoc for phen_group
    mc = MultiComparison(df['estimate'], df['phen_group'])
    posthoc_results = mc.tukeyhsd()
    print("\n\n Post Hoc for phen_group - absolute value \n\n")
    print(posthoc_results)
# Out:
# /var/folders/tx/3z8_jq352fd7z_0llwbf29380000gp/T/ipykernel_650/1067996279.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = anova_results['PR(>F)'][0]
# /var/folders/tx/3z8_jq352fd7z_0llwbf29380000gp/T/ipykernel_650/1067996279.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = anova_results['PR(>F)'][0]
# /var/folders/tx/3z8_jq352fd7z_0llwbf29380000gp/T/ipykernel_650/1067996279.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = anova_results['PR(>F)'][0]
# /var/folders/tx/3z8_jq352fd7z_0llwbf29380000gp/T/ipykernel_650/1067996279.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = anova_results['PR(>F)'][0]
# /var/folders/tx/3z8_jq352fd7z_0llwbf29380000gp/T/ipykernel_650/1067996279.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = anova_results['PR(>F)'][0]
#  One-Way ANOVA with depression phenotype group on Gray Matter Volume results - with FDR correction
#
#
#                  sum_sq     df         F    PR(>F)     P_FDR
# C(phen_group)  0.000609    1.0  3.520366  0.062511  0.104186
# Residual       0.026630  154.0       NaN       NaN       NaN
#
#
#  Post Hoc for phen_group - absolute value
#
#
#     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ============================================================
#   group1      group2   meandiff p-adj   lower  upper  reject
# ------------------------------------------------------------
# Depression Neuroticism   -0.004 0.0625 -0.0081 0.0002  False
# ------------------------------------------------------------
#
#
#  One-Way ANOVA with depression phenotype group on Cortical Surface Area results - with FDR correction
#
#
#                  sum_sq     df        F    PR(>F)     P_FDR
# C(phen_group)  0.000298    1.0  1.79844  0.182393  0.227991
# Residual       0.020187  122.0      NaN       NaN       NaN
#
#
#  Post Hoc for phen_group - absolute value
#
#
#     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ============================================================
#   group1      group2   meandiff p-adj   lower  upper  reject
# ------------------------------------------------------------
# Depression Neuroticism  -0.0031 0.1824 -0.0077 0.0015  False
# ------------------------------------------------------------
#
#
#  One-Way ANOVA with depression phenotype group on Cortical Thickness results - with FDR correction
#
#
#                  sum_sq     df         F    PR(>F)     P_FDR
# C(phen_group)  0.000003    1.0  0.094655  0.758865  0.758865
# Residual       0.004021  122.0       NaN       NaN       NaN
#
#
#  Post Hoc for phen_group - absolute value
#
#
#     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ============================================================
#   group1      group2   meandiff p-adj   lower  upper  reject
# ------------------------------------------------------------
# Depression Neuroticism   0.0003 0.7589 -0.0017 0.0024  False
# ------------------------------------------------------------
#
#
#  One-Way ANOVA with depression phenotype group on Partial Netmats (Schaefer) results - with FDR correction
#
#
#                  sum_sq       df          F    PR(>F)     P_FDR
# C(phen_group)  0.000297      1.0  13.481371  0.000241  0.000603
# Residual       1.978732  89698.0        NaN       NaN       NaN
#
#
#  Post Hoc for phen_group - absolute value
#
#
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =============================================================
#   group1      group2   meandiff p-adj   lower   upper  reject
# -------------------------------------------------------------
# Depression Neuroticism  -0.0001 0.0002 -0.0002 -0.0001   True
# -------------------------------------------------------------
#
#
#  One-Way ANOVA with depression phenotype group on Full Netmats (Schaefer) results - with FDR correction
#
#
#                  sum_sq       df           F        PR(>F)         P_FDR
# C(phen_group)  0.019156      1.0  386.769463  6.348345e-86  3.174173e-85
# Residual       4.442597  89698.0         NaN           NaN           NaN
#
#
#  Post Hoc for phen_group - absolute value
#
#
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================
#   group1      group2   meandiff p-adj lower  upper reject
# ---------------------------------------------------------
# Depression Neuroticism   0.0009   0.0 0.0008 0.001   True
# ---------------------------------------------------------

# %%
# perform two-way ANOVA
model = ols("""estimate ~ C(phen_group) + C(imaging_metric) + C(phen_group):C(imaging_metric)""", data=df_total).fit()
print("\n\n Two-Way ANOVA with phen_group and image data type (absolute value) \n\n")
print((sm.stats.anova_lm(model, typ=2)))

# post_hoc for phen_group
mc = MultiComparison(df_total['estimate'], df_total['phen_group'])
posthoc_results = mc.tukeyhsd()
print("\n\n Post Hoc for phen_group - absolute value \n\n")
print(posthoc_results)

# post_hoc for brain data type
mc = MultiComparison(df_total['estimate'], df_total['imaging_metric'])
posthoc_results = mc.tukeyhsd()
print("\n\n Post Hoc for imaging metric (absolute val) \n\n")
print(posthoc_results)

# post_hoc for brain data type
mc = MultiComparison(df_total['estimate'], df_total['imaging_metric']+df_total['phen_group'])
posthoc_results = mc.tukeyhsd()
print("\n\n Post Hoc for interaction effect (absolute val) \n\n")
print(posthoc_results)
# Out:
#  Two-Way ANOVA with phen_group and image data type (absolute value)
#
#
#                                    sum_sq        df            F        PR(>F)
# C(phen_group)                    0.007131       1.0   198.088055  5.767500e-45
# C(imaging_metric)                0.731713       4.0  5081.666750  0.000000e+00
# C(phen_group):C(imaging_metric)  0.013232       4.0    91.896191  3.367201e-78
# Residual                         6.472166  179794.0          NaN           NaN
#
#
#  Post Hoc for phen_group - absolute value
#
#
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==========================================================
#   group1      group2   meandiff p-adj lower  upper  reject
# ----------------------------------------------------------
# Depression Neuroticism   0.0004   0.0 0.0003 0.0005   True
# ----------------------------------------------------------
#
#
#  Post Hoc for imaging metric (absolute val)
#
#
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#          group1                   group2           meandiff p-adj   lower   upper  reject
# -----------------------------------------------------------------------------------------
#   Cortical Surface Area         Cortical Thickness  -0.0235    0.0 -0.0256 -0.0214   True
#   Cortical Surface Area    Full Netmats (Schaefer)   -0.021    0.0 -0.0225 -0.0196   True
#   Cortical Surface Area         Gray Matter Volume   -0.009    0.0  -0.011 -0.0071   True
#   Cortical Surface Area Partial Netmats (Schaefer)  -0.0248    0.0 -0.0263 -0.0233   True
#      Cortical Thickness    Full Netmats (Schaefer)   0.0025    0.0   0.001  0.0039   True
#      Cortical Thickness         Gray Matter Volume   0.0145    0.0  0.0125  0.0164   True
#      Cortical Thickness Partial Netmats (Schaefer)  -0.0013 0.1171 -0.0028  0.0002  False
# Full Netmats (Schaefer)         Gray Matter Volume    0.012    0.0  0.0107  0.0133   True
# Full Netmats (Schaefer) Partial Netmats (Schaefer)  -0.0038    0.0 -0.0038 -0.0037   True
#      Gray Matter Volume Partial Netmats (Schaefer)  -0.0158    0.0 -0.0171 -0.0145   True
# -----------------------------------------------------------------------------------------
#
#
#  Post Hoc for interaction effect (absolute val)
#
#
#                                Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================================================================================
#                group1                                group2                meandiff p-adj   lower   upper  reject
# -----------------------------------------------------------------------------------------------------------------
#      Cortical Surface AreaDepression      Cortical Surface AreaNeuroticism  -0.0031 0.1125 -0.0065  0.0003  False
#      Cortical Surface AreaDepression          Cortical ThicknessDepression  -0.0252    0.0 -0.0286 -0.0218   True
#      Cortical Surface AreaDepression         Cortical ThicknessNeuroticism  -0.0249    0.0 -0.0283 -0.0215   True
#      Cortical Surface AreaDepression     Full Netmats (Schaefer)Depression   -0.023    0.0 -0.0255 -0.0206   True
#      Cortical Surface AreaDepression    Full Netmats (Schaefer)Neuroticism  -0.0221    0.0 -0.0245 -0.0197   True
#      Cortical Surface AreaDepression          Gray Matter VolumeDepression  -0.0086    0.0 -0.0118 -0.0054   True
#      Cortical Surface AreaDepression         Gray Matter VolumeNeuroticism  -0.0126    0.0 -0.0158 -0.0093   True
#      Cortical Surface AreaDepression  Partial Netmats (Schaefer)Depression  -0.0263    0.0 -0.0287 -0.0239   True
#      Cortical Surface AreaDepression Partial Netmats (Schaefer)Neuroticism  -0.0264    0.0 -0.0288  -0.024   True
#     Cortical Surface AreaNeuroticism          Cortical ThicknessDepression  -0.0221    0.0 -0.0255 -0.0187   True
#     Cortical Surface AreaNeuroticism         Cortical ThicknessNeuroticism  -0.0218    0.0 -0.0252 -0.0184   True
#     Cortical Surface AreaNeuroticism     Full Netmats (Schaefer)Depression  -0.0199    0.0 -0.0224 -0.0175   True
#     Cortical Surface AreaNeuroticism    Full Netmats (Schaefer)Neuroticism   -0.019    0.0 -0.0214 -0.0166   True
#     Cortical Surface AreaNeuroticism          Gray Matter VolumeDepression  -0.0055    0.0 -0.0087 -0.0023   True
#     Cortical Surface AreaNeuroticism         Gray Matter VolumeNeuroticism  -0.0095    0.0 -0.0127 -0.0062   True
#     Cortical Surface AreaNeuroticism  Partial Netmats (Schaefer)Depression  -0.0232    0.0 -0.0256 -0.0208   True
#     Cortical Surface AreaNeuroticism Partial Netmats (Schaefer)Neuroticism  -0.0233    0.0 -0.0257 -0.0209   True
#         Cortical ThicknessDepression         Cortical ThicknessNeuroticism   0.0003    1.0 -0.0031  0.0037  False
#         Cortical ThicknessDepression     Full Netmats (Schaefer)Depression   0.0022 0.1207 -0.0002  0.0046  False
#         Cortical ThicknessDepression    Full Netmats (Schaefer)Neuroticism   0.0031  0.002  0.0007  0.0055   True
#         Cortical ThicknessDepression          Gray Matter VolumeDepression   0.0166    0.0  0.0134  0.0198   True
#         Cortical ThicknessDepression         Gray Matter VolumeNeuroticism   0.0127    0.0  0.0094  0.0159   True
#         Cortical ThicknessDepression  Partial Netmats (Schaefer)Depression  -0.0011 0.9241 -0.0035  0.0013  False
#         Cortical ThicknessDepression Partial Netmats (Schaefer)Neuroticism  -0.0012 0.8662 -0.0036  0.0012  False
#        Cortical ThicknessNeuroticism     Full Netmats (Schaefer)Depression   0.0019 0.3065 -0.0006  0.0043  False
#        Cortical ThicknessNeuroticism    Full Netmats (Schaefer)Neuroticism   0.0028 0.0101  0.0004  0.0052   True
#        Cortical ThicknessNeuroticism          Gray Matter VolumeDepression   0.0163    0.0  0.0131  0.0195   True
#        Cortical ThicknessNeuroticism         Gray Matter VolumeNeuroticism   0.0123    0.0  0.0091  0.0156   True
#        Cortical ThicknessNeuroticism  Partial Netmats (Schaefer)Depression  -0.0014 0.7179 -0.0038   0.001  False
#        Cortical ThicknessNeuroticism Partial Netmats (Schaefer)Neuroticism  -0.0015 0.6144 -0.0039  0.0009  False
#    Full Netmats (Schaefer)Depression    Full Netmats (Schaefer)Neuroticism   0.0009    0.0  0.0008  0.0011   True
#    Full Netmats (Schaefer)Depression          Gray Matter VolumeDepression   0.0144    0.0  0.0123  0.0166   True
#    Full Netmats (Schaefer)Depression         Gray Matter VolumeNeuroticism   0.0105    0.0  0.0083  0.0126   True
#    Full Netmats (Schaefer)Depression  Partial Netmats (Schaefer)Depression  -0.0032    0.0 -0.0034 -0.0031   True
#    Full Netmats (Schaefer)Depression Partial Netmats (Schaefer)Neuroticism  -0.0034    0.0 -0.0035 -0.0032   True
#   Full Netmats (Schaefer)Neuroticism          Gray Matter VolumeDepression   0.0135    0.0  0.0114  0.0157   True
#   Full Netmats (Schaefer)Neuroticism         Gray Matter VolumeNeuroticism   0.0096    0.0  0.0074  0.0117   True
#   Full Netmats (Schaefer)Neuroticism  Partial Netmats (Schaefer)Depression  -0.0042    0.0 -0.0043  -0.004   True
#   Full Netmats (Schaefer)Neuroticism Partial Netmats (Schaefer)Neuroticism  -0.0043    0.0 -0.0044 -0.0042   True
#         Gray Matter VolumeDepression         Gray Matter VolumeNeuroticism   -0.004 0.0016  -0.007 -0.0009   True
#         Gray Matter VolumeDepression  Partial Netmats (Schaefer)Depression  -0.0177    0.0 -0.0198 -0.0155   True
#         Gray Matter VolumeDepression Partial Netmats (Schaefer)Neuroticism  -0.0178    0.0 -0.0199 -0.0156   True
#        Gray Matter VolumeNeuroticism  Partial Netmats (Schaefer)Depression  -0.0137    0.0 -0.0159 -0.0116   True
#        Gray Matter VolumeNeuroticism Partial Netmats (Schaefer)Neuroticism  -0.0138    0.0  -0.016 -0.0117   True
# Partial Netmats (Schaefer)Depression Partial Netmats (Schaefer)Neuroticism  -0.0001 0.1128 -0.0002     0.0  False
# -----------------------------------------------------------------------------------------------------------------

# %%
### SPATIAL --> 6X main effect of yeo and depression phenotype (with FDR correction) 

# List to store p-values from ANOVA tests
all_p_values = []

for df in all_dfs:
    # Perform two-way ANOVA
    model = ols("""estimate ~ C(phen_group) + C(Yeo_name) + C(phen_group):C(Yeo_name)""", data=df).fit()
    img_met = df["imaging_metric"].unique()[0]
    anova_results = sm.stats.anova_lm(model, typ=2)
    print(f"\n\n Two-Way ANOVA with Yeo_name and phen_group on {img_met} results - absolute value \n\n")
    print(anova_results)

    # Collect p-values for FDR correction
    p_values = anova_results['PR(>F)'].tolist()
    all_p_values.extend(p_values[:-1])  # Exclude the last p-value which is NaN for the residual

    # Post hoc for Yeo_name
    mc = MultiComparison(df['estimate'], df['Yeo_name'])
    posthoc_results = mc.tukeyhsd()
    print("\n\n Post Hoc for Yeo_name - absolute value \n\n")
    print(posthoc_results)

    # Post hoc for phen_group
    mc = MultiComparison(df['estimate'], df['phen_group'])
    posthoc_results = mc.tukeyhsd()
    print("\n\n Post Hoc for phen_group - absolute value \n\n")
    print(posthoc_results)

    # post hoc for interaction effect
    mc = MultiComparison(df['estimate'], df['Yeo_name']+df['phen_group'])
    posthoc_results = mc.tukeyhsd()
    print("\n\n Post Hoc for phen_group - absolute value \n\n")
    print(posthoc_results)

# # Apply FDR correction to the collected p-values
# _, corrected_p_values, _, _ = multipletests(all_p_values, alpha=0.05, method='fdr_bh')

# # Iterate through the dataframes again to add the corrected p-values
# corrected_p_index = 0
# for df in all_dfs:
#     # Perform two-way ANOVA again to get the anova_results DataFrame
#     model = ols("""estimate ~ C(phen_group) + C(Yeo_name) + C(phen_group):C(Yeo_name)""", data=df).fit()
#     anova_results = sm.stats.anova_lm(model, typ=2)
#     img_met = df["imaging_metric"].unique()[0]

#     # Add a new column for FDR corrected p-values
#     num_effects = len(anova_results) - 1  # Exclude the residual row
#     anova_results['P_FDR'] = [None] * len(anova_results)  # Initialize with None
#     anova_results.iloc[:num_effects, anova_results.columns.get_loc('P_FDR')] = corrected_p_values[corrected_p_index:corrected_p_index + num_effects]
#     corrected_p_index += num_effects

#     # Print the anova_results with the new column
#     print(f"\n\n Two-Way ANOVA with Yeo_name and phen_group on {img_met} results - with FDR correction \n\n")
#     print(anova_results)

#         # Post hoc for Yeo_name
#     mc = MultiComparison(df['estimate'], df['Yeo_name'])
#     posthoc_results = mc.tukeyhsd()
#     print("\n\n Post Hoc for Yeo_name - absolute value \n\n")
#     print(posthoc_results)

#     # Post hoc for phen_group
#     mc = MultiComparison(df['estimate'], df['phen_group'])
#     posthoc_results = mc.tukeyhsd()
#     print("\n\n Post Hoc for phen_group - absolute value \n\n")
#     print(posthoc_results)

#     # post hoc for interaction effect
#     mc = MultiComparison(df['estimate'], df['Yeo_name']+df['phen_group'])
#     posthoc_results = mc.tukeyhsd()
#     print("\n\n Post Hoc for phen_group - absolute value \n\n")
#     print(posthoc_results)
# Out:
#  Two-Way ANOVA with Yeo_name and phen_group on Gray Matter Volume results - absolute value
#
#
#                              sum_sq     df          F        PR(>F)
# C(phen_group)              0.000609    1.0   5.164601  2.457491e-02
# C(Yeo_name)                0.008324    7.0  10.088409  3.516689e-10
# C(phen_group):C(Yeo_name)  0.001804    7.0   2.186996  3.886734e-02
# Residual                   0.016502  140.0        NaN           NaN
#
#
#  Post Hoc for Yeo_name - absolute value
#
#
#            Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==========================================================================
#       group1            group2      meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------------------
#           Default  Dorsal Attention  -0.0108 0.6096 -0.0291  0.0075  False
#           Default    Frontoparietal   0.0038 0.9898 -0.0098  0.0173  False
#           Default            Limbic  -0.0047 0.8642 -0.0151  0.0058  False
#           Default       Somatomotor  -0.0036   0.95 -0.0132  0.0061  False
#           Default       Subcortical  -0.0192    0.0 -0.0277 -0.0108   True
#           Default Ventral Attention  -0.0013 0.9999 -0.0113  0.0088  False
#           Default            Visual  -0.0073 0.2569 -0.0167  0.0021  False
#  Dorsal Attention    Frontoparietal   0.0146 0.4157 -0.0067  0.0359  False
#  Dorsal Attention            Limbic   0.0061 0.9779 -0.0133  0.0256  False
#  Dorsal Attention       Somatomotor   0.0073 0.9379 -0.0118  0.0263  False
#  Dorsal Attention       Subcortical  -0.0084 0.8562 -0.0268    0.01  False
#  Dorsal Attention Ventral Attention   0.0095 0.7911 -0.0097  0.0288  False
#  Dorsal Attention            Visual   0.0035 0.9991 -0.0154  0.0224  False
#    Frontoparietal            Limbic  -0.0084 0.6703 -0.0235  0.0066  False
#    Frontoparietal       Somatomotor  -0.0073 0.7815 -0.0218  0.0072  False
#    Frontoparietal       Subcortical   -0.023    0.0 -0.0367 -0.0092   True
#    Frontoparietal Ventral Attention   -0.005 0.9661 -0.0198  0.0097  False
#    Frontoparietal            Visual  -0.0111 0.2652 -0.0254  0.0033  False
#            Limbic       Somatomotor   0.0011    1.0 -0.0105  0.0128  False
#            Limbic       Subcortical  -0.0145 0.0012 -0.0252 -0.0039   True
#            Limbic Ventral Attention   0.0034 0.9875 -0.0085  0.0154  False
#            Limbic            Visual  -0.0026 0.9969  -0.014  0.0088  False
#       Somatomotor       Subcortical  -0.0157 0.0001 -0.0256 -0.0058   True
#       Somatomotor Ventral Attention   0.0023 0.9986  -0.009  0.0136  False
#       Somatomotor            Visual  -0.0037 0.9617 -0.0145   0.007  False
#       Subcortical Ventral Attention   0.0179    0.0  0.0077  0.0282   True
#       Subcortical            Visual   0.0119 0.0049  0.0023  0.0216   True
# Ventral Attention            Visual   -0.006 0.7036 -0.0171   0.005  False
# --------------------------------------------------------------------------
#
#
#  Post Hoc for phen_group - absolute value
#
#
#     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ============================================================
#   group1      group2   meandiff p-adj   lower  upper  reject
# ------------------------------------------------------------
# Depression Neuroticism   -0.004 0.0625 -0.0081 0.0002  False
# ------------------------------------------------------------
#
#
#  Post Hoc for phen_group - absolute value
#
#
#                       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================================================================
#            group1                       group2            meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------------------------------------
#            DefaultDepression           DefaultNeuroticism  -0.0063 0.9347 -0.0189  0.0064  False
#            DefaultDepression   Dorsal AttentionDepression  -0.0021    1.0 -0.0303  0.0262  False
#            DefaultDepression  Dorsal AttentionNeuroticism  -0.0258  0.114 -0.0541  0.0024  False
#            DefaultDepression     FrontoparietalDepression  -0.0015    1.0 -0.0224  0.0195  False
#            DefaultDepression    FrontoparietalNeuroticism   0.0027    1.0 -0.0182  0.0237  False
#            DefaultDepression             LimbicDepression  -0.0105 0.6375 -0.0266  0.0056  False
#            DefaultDepression            LimbicNeuroticism  -0.0051 0.9992 -0.0212   0.011  False
#            DefaultDepression        SomatomotorDepression   -0.001    1.0 -0.0159   0.014  False
#            DefaultDepression       SomatomotorNeuroticism  -0.0124 0.2322 -0.0273  0.0026  False
#            DefaultDepression        SubcorticalDepression  -0.0208    0.0 -0.0338 -0.0078   True
#            DefaultDepression       SubcorticalNeuroticism  -0.0239    0.0 -0.0369 -0.0109   True
#            DefaultDepression  Ventral AttentionDepression   0.0008    1.0 -0.0146  0.0163  False
#            DefaultDepression Ventral AttentionNeuroticism  -0.0097 0.7108 -0.0251  0.0058  False
#            DefaultDepression             VisualDepression  -0.0128 0.1549 -0.0273  0.0017  False
#            DefaultDepression            VisualNeuroticism  -0.0081 0.8479 -0.0226  0.0064  False
#           DefaultNeuroticism   Dorsal AttentionDepression   0.0042    1.0 -0.0241  0.0324  False
#           DefaultNeuroticism  Dorsal AttentionNeuroticism  -0.0196 0.5374 -0.0478  0.0087  False
#           DefaultNeuroticism     FrontoparietalDepression   0.0048    1.0 -0.0161  0.0257  False
#           DefaultNeuroticism    FrontoparietalNeuroticism    0.009 0.9813  -0.012  0.0299  False
#           DefaultNeuroticism             LimbicDepression  -0.0043 0.9999 -0.0204  0.0118  False
#           DefaultNeuroticism            LimbicNeuroticism   0.0011    1.0  -0.015  0.0172  False
#           DefaultNeuroticism        SomatomotorDepression   0.0053 0.9973 -0.0097  0.0202  False
#           DefaultNeuroticism       SomatomotorNeuroticism  -0.0061 0.9879 -0.0211  0.0088  False
#           DefaultNeuroticism        SubcorticalDepression  -0.0145 0.0141 -0.0275 -0.0015   True
#           DefaultNeuroticism       SubcorticalNeuroticism  -0.0177 0.0006 -0.0307 -0.0046   True
#           DefaultNeuroticism  Ventral AttentionDepression   0.0071 0.9657 -0.0084  0.0226  False
#           DefaultNeuroticism Ventral AttentionNeuroticism  -0.0034    1.0 -0.0189  0.0121  False
#           DefaultNeuroticism             VisualDepression  -0.0065 0.9724  -0.021   0.008  False
#           DefaultNeuroticism            VisualNeuroticism  -0.0018    1.0 -0.0163  0.0127  False
#   Dorsal AttentionDepression  Dorsal AttentionNeuroticism  -0.0238  0.704 -0.0616  0.0141  False
#   Dorsal AttentionDepression     FrontoparietalDepression   0.0006    1.0 -0.0322  0.0334  False
#   Dorsal AttentionDepression    FrontoparietalNeuroticism   0.0048    1.0  -0.028  0.0376  False
#   Dorsal AttentionDepression             LimbicDepression  -0.0084 0.9998 -0.0384  0.0215  False
#   Dorsal AttentionDepression            LimbicNeuroticism   -0.003    1.0  -0.033  0.0269  False
#   Dorsal AttentionDepression        SomatomotorDepression   0.0011    1.0 -0.0282  0.0304  False
#   Dorsal AttentionDepression       SomatomotorNeuroticism  -0.0103 0.9975 -0.0396   0.019  False
#   Dorsal AttentionDepression        SubcorticalDepression  -0.0187 0.6282 -0.0471  0.0097  False
#   Dorsal AttentionDepression       SubcorticalNeuroticism  -0.0218 0.3521 -0.0503  0.0066  False
#   Dorsal AttentionDepression  Ventral AttentionDepression   0.0029    1.0 -0.0267  0.0325  False
#   Dorsal AttentionDepression Ventral AttentionNeuroticism  -0.0076 0.9999 -0.0372   0.022  False
#   Dorsal AttentionDepression             VisualDepression  -0.0107 0.9961 -0.0398  0.0184  False
#   Dorsal AttentionDepression            VisualNeuroticism   -0.006    1.0 -0.0351  0.0231  False
#  Dorsal AttentionNeuroticism     FrontoparietalDepression   0.0244 0.4129 -0.0084  0.0572  False
#  Dorsal AttentionNeuroticism    FrontoparietalNeuroticism   0.0285 0.1679 -0.0043  0.0614  False
#  Dorsal AttentionNeuroticism             LimbicDepression   0.0153 0.9181 -0.0146  0.0453  False
#  Dorsal AttentionNeuroticism            LimbicNeuroticism   0.0207 0.5415 -0.0092  0.0507  False
#  Dorsal AttentionNeuroticism        SomatomotorDepression   0.0249 0.2024 -0.0045  0.0542  False
#  Dorsal AttentionNeuroticism       SomatomotorNeuroticism   0.0134  0.966 -0.0159  0.0428  False
#  Dorsal AttentionNeuroticism        SubcorticalDepression   0.0051    1.0 -0.0233  0.0335  False
#  Dorsal AttentionNeuroticism       SubcorticalNeuroticism   0.0019    1.0 -0.0265  0.0303  False
#  Dorsal AttentionNeuroticism  Ventral AttentionDepression   0.0267 0.1297 -0.0029  0.0563  False
#  Dorsal AttentionNeuroticism Ventral AttentionNeuroticism   0.0162 0.8684 -0.0134  0.0458  False
#  Dorsal AttentionNeuroticism             VisualDepression   0.0131 0.9715  -0.016  0.0422  False
#  Dorsal AttentionNeuroticism            VisualNeuroticism   0.0177 0.7457 -0.0114  0.0469  False
#     FrontoparietalDepression    FrontoparietalNeuroticism   0.0042    1.0 -0.0226   0.031  False
#     FrontoparietalDepression             LimbicDepression  -0.0091 0.9924 -0.0323  0.0141  False
#     FrontoparietalDepression            LimbicNeuroticism  -0.0037    1.0 -0.0269  0.0195  False
#     FrontoparietalDepression        SomatomotorDepression   0.0005    1.0 -0.0219  0.0229  False
#     FrontoparietalDepression       SomatomotorNeuroticism  -0.0109 0.9435 -0.0333  0.0115  False
#     FrontoparietalDepression        SubcorticalDepression  -0.0193 0.1176 -0.0405  0.0019  False
#     FrontoparietalDepression       SubcorticalNeuroticism  -0.0225  0.026 -0.0436 -0.0013   True
#     FrontoparietalDepression  Ventral AttentionDepression   0.0023    1.0 -0.0205  0.0251  False
#     FrontoparietalDepression Ventral AttentionNeuroticism  -0.0082 0.9968  -0.031  0.0146  False
#     FrontoparietalDepression             VisualDepression  -0.0113  0.919 -0.0334  0.0108  False
#     FrontoparietalDepression            VisualNeuroticism  -0.0066 0.9996 -0.0288  0.0155  False
#    FrontoparietalNeuroticism             LimbicDepression  -0.0132 0.8258 -0.0364    0.01  False
#    FrontoparietalNeuroticism            LimbicNeuroticism  -0.0078 0.9984  -0.031  0.0154  False
#    FrontoparietalNeuroticism        SomatomotorDepression  -0.0037    1.0 -0.0261  0.0187  False
#    FrontoparietalNeuroticism       SomatomotorNeuroticism  -0.0151 0.5871 -0.0375  0.0073  False
#    FrontoparietalNeuroticism        SubcorticalDepression  -0.0235  0.015 -0.0447 -0.0023   True
#    FrontoparietalNeuroticism       SubcorticalNeuroticism  -0.0266 0.0023 -0.0478 -0.0055   True
#    FrontoparietalNeuroticism  Ventral AttentionDepression  -0.0019    1.0 -0.0246  0.0209  False
#    FrontoparietalNeuroticism Ventral AttentionNeuroticism  -0.0124 0.8737 -0.0351  0.0104  False
#    FrontoparietalNeuroticism             VisualDepression  -0.0155 0.5213 -0.0376  0.0067  False
#    FrontoparietalNeuroticism            VisualNeuroticism  -0.0108  0.942 -0.0329  0.0113  False
#             LimbicDepression            LimbicNeuroticism   0.0054 0.9998 -0.0135  0.0243  False
#             LimbicDepression        SomatomotorDepression   0.0095 0.8919 -0.0084  0.0275  False
#             LimbicDepression       SomatomotorNeuroticism  -0.0019    1.0 -0.0198  0.0161  False
#             LimbicDepression        SubcorticalDepression  -0.0102 0.7102 -0.0266  0.0062  False
#             LimbicDepression       SubcorticalNeuroticism  -0.0134 0.2533 -0.0298   0.003  False
#             LimbicDepression  Ventral AttentionDepression   0.0114 0.7276 -0.0071  0.0298  False
#             LimbicDepression Ventral AttentionNeuroticism   0.0009    1.0 -0.0175  0.0193  False
#             LimbicDepression             VisualDepression  -0.0022    1.0 -0.0198  0.0154  False
#             LimbicDepression            VisualNeuroticism   0.0024    1.0 -0.0152    0.02  False
#            LimbicNeuroticism        SomatomotorDepression   0.0041    1.0 -0.0138  0.0221  False
#            LimbicNeuroticism       SomatomotorNeuroticism  -0.0073 0.9894 -0.0252  0.0107  False
#            LimbicNeuroticism        SubcorticalDepression  -0.0156 0.0795  -0.032  0.0008  False
#            LimbicNeuroticism       SubcorticalNeuroticism  -0.0188 0.0095 -0.0352 -0.0024   True
#            LimbicNeuroticism  Ventral AttentionDepression    0.006  0.999 -0.0125  0.0244  False
#            LimbicNeuroticism Ventral AttentionNeuroticism  -0.0045    1.0 -0.0229  0.0139  False
#            LimbicNeuroticism             VisualDepression  -0.0076 0.9793 -0.0252    0.01  False
#            LimbicNeuroticism            VisualNeuroticism   -0.003    1.0 -0.0206  0.0146  False
#        SomatomotorDepression       SomatomotorNeuroticism  -0.0114 0.5887 -0.0283  0.0055  False
#        SomatomotorDepression        SubcorticalDepression  -0.0198 0.0014 -0.0351 -0.0045   True
#        SomatomotorDepression       SubcorticalNeuroticism  -0.0229 0.0001 -0.0382 -0.0077   True
#        SomatomotorDepression  Ventral AttentionDepression   0.0018    1.0 -0.0156  0.0192  False
#        SomatomotorDepression Ventral AttentionNeuroticism  -0.0087 0.9328 -0.0261  0.0087  False
#        SomatomotorDepression             VisualDepression  -0.0118  0.491 -0.0283  0.0048  False
#        SomatomotorDepression            VisualNeuroticism  -0.0071 0.9808 -0.0237  0.0094  False
#       SomatomotorNeuroticism        SubcorticalDepression  -0.0084 0.8645 -0.0237  0.0069  False
#       SomatomotorNeuroticism       SubcorticalNeuroticism  -0.0115 0.3815 -0.0268  0.0037  False
#       SomatomotorNeuroticism  Ventral AttentionDepression   0.0132  0.374 -0.0042  0.0306  False
#       SomatomotorNeuroticism Ventral AttentionNeuroticism   0.0027    1.0 -0.0147  0.0201  False
#       SomatomotorNeuroticism             VisualDepression  -0.0004    1.0 -0.0169  0.0162  False
#       SomatomotorNeuroticism            VisualNeuroticism   0.0043 0.9999 -0.0123  0.0208  False
#        SubcorticalDepression       SubcorticalNeuroticism  -0.0032    1.0 -0.0166  0.0102  False
#        SubcorticalDepression  Ventral AttentionDepression   0.0216 0.0005  0.0058  0.0374   True
#        SubcorticalDepression Ventral AttentionNeuroticism   0.0111 0.5086 -0.0047  0.0269  False
#        SubcorticalDepression             VisualDepression    0.008 0.8785 -0.0068  0.0229  False
#        SubcorticalDepression            VisualNeuroticism   0.0127 0.1915 -0.0022  0.0275  False
#       SubcorticalNeuroticism  Ventral AttentionDepression   0.0248    0.0   0.009  0.0405   True
#       SubcorticalNeuroticism Ventral AttentionNeuroticism   0.0143 0.1249 -0.0015  0.0301  False
#       SubcorticalNeuroticism             VisualDepression   0.0112  0.388 -0.0037   0.026  False
#       SubcorticalNeuroticism            VisualNeuroticism   0.0158 0.0242   0.001  0.0307   True
#  Ventral AttentionDepression Ventral AttentionNeuroticism  -0.0105 0.7936 -0.0283  0.0074  False
#  Ventral AttentionDepression             VisualDepression  -0.0136 0.2907 -0.0306  0.0034  False
#  Ventral AttentionDepression            VisualNeuroticism  -0.0089 0.9012  -0.026  0.0081  False
# Ventral AttentionNeuroticism             VisualDepression  -0.0031    1.0 -0.0201  0.0139  False
# Ventral AttentionNeuroticism            VisualNeuroticism   0.0016    1.0 -0.0155  0.0186  False
#             VisualDepression            VisualNeuroticism   0.0047 0.9997 -0.0115  0.0208  False
# ------------------------------------------------------------------------------------------------
#
#
#  Two-Way ANOVA with Yeo_name and phen_group on Cortical Surface Area results - absolute value
#
#
#                              sum_sq     df         F    PR(>F)
# C(phen_group)              0.000298    1.0  1.834882  0.178328
# C(Yeo_name)                0.001289    6.0  1.324159  0.252435
# C(phen_group):C(Yeo_name)  0.001059    6.0  1.087849  0.374212
# Residual                   0.017840  110.0       NaN       NaN
#
#
#  Post Hoc for Yeo_name - absolute value
#
#
#            Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================
#       group1            group2      meandiff p-adj   lower  upper  reject
# -------------------------------------------------------------------------
#           Default  Dorsal Attention  -0.0085 0.8708 -0.0287 0.0118  False
#           Default    Frontoparietal   0.0038 0.9877 -0.0112 0.0189  False
#           Default            Limbic  -0.0026 0.9941 -0.0141  0.009  False
#           Default       Somatomotor  -0.0029  0.983 -0.0136 0.0078  False
#           Default Ventral Attention  -0.0038 0.9486 -0.0149 0.0073  False
#           Default            Visual  -0.0076 0.3065  -0.018 0.0028  False
#  Dorsal Attention    Frontoparietal   0.0123 0.7025 -0.0112 0.0358  False
#  Dorsal Attention            Limbic   0.0059  0.982 -0.0156 0.0274  False
#  Dorsal Attention       Somatomotor   0.0056 0.9853 -0.0155 0.0266  False
#  Dorsal Attention Ventral Attention   0.0047 0.9943 -0.0165 0.0259  False
#  Dorsal Attention            Visual   0.0009    1.0   -0.02 0.0218  False
#    Frontoparietal            Limbic  -0.0064 0.9093  -0.023 0.0102  False
#    Frontoparietal       Somatomotor  -0.0067 0.8691 -0.0228 0.0093  False
#    Frontoparietal Ventral Attention  -0.0076 0.8025 -0.0239 0.0087  False
#    Frontoparietal            Visual  -0.0114 0.3234 -0.0273 0.0044  False
#            Limbic       Somatomotor  -0.0003    1.0 -0.0132 0.0125  False
#            Limbic Ventral Attention  -0.0012    1.0 -0.0144  0.012  False
#            Limbic            Visual   -0.005 0.8941 -0.0177 0.0076  False
#       Somatomotor Ventral Attention  -0.0009    1.0 -0.0133 0.0116  False
#       Somatomotor            Visual  -0.0047 0.8978 -0.0166 0.0072  False
# Ventral Attention            Visual  -0.0038 0.9647 -0.0161 0.0084  False
# -------------------------------------------------------------------------
#
#
#  Post Hoc for phen_group - absolute value
#
#
#     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ============================================================
#   group1      group2   meandiff p-adj   lower  upper  reject
# ------------------------------------------------------------
# Depression Neuroticism  -0.0031 0.1824 -0.0077 0.0015  False
# ------------------------------------------------------------
#
#
#  Post Hoc for phen_group - absolute value
#
#
#                       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================================================
#            group1                       group2            meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------------
#            DefaultDepression           DefaultNeuroticism  -0.0078 0.8534 -0.0224 0.0068  False
#            DefaultDepression   Dorsal AttentionDepression  -0.0037    1.0 -0.0362 0.0289  False
#            DefaultDepression  Dorsal AttentionNeuroticism  -0.0211 0.6151 -0.0536 0.0115  False
#            DefaultDepression     FrontoparietalDepression  -0.0023    1.0 -0.0264 0.0219  False
#            DefaultDepression    FrontoparietalNeuroticism   0.0021    1.0  -0.022 0.0263  False
#            DefaultDepression             LimbicDepression  -0.0089 0.9275 -0.0275 0.0096  False
#            DefaultDepression            LimbicNeuroticism   -0.004    1.0 -0.0226 0.0146  False
#            DefaultDepression        SomatomotorDepression  -0.0044 0.9998 -0.0217 0.0128  False
#            DefaultDepression       SomatomotorNeuroticism  -0.0092 0.8587 -0.0264  0.008  False
#            DefaultDepression  Ventral AttentionDepression  -0.0043 0.9999 -0.0221 0.0135  False
#            DefaultDepression Ventral AttentionNeuroticism   -0.011 0.6845 -0.0289 0.0068  False
#            DefaultDepression             VisualDepression  -0.0131 0.3047 -0.0298 0.0037  False
#            DefaultDepression            VisualNeuroticism    -0.01  0.737 -0.0267 0.0068  False
#           DefaultNeuroticism   Dorsal AttentionDepression   0.0041    1.0 -0.0284 0.0367  False
#           DefaultNeuroticism  Dorsal AttentionNeuroticism  -0.0133 0.9802 -0.0458 0.0193  False
#           DefaultNeuroticism     FrontoparietalDepression   0.0055 0.9999 -0.0186 0.0297  False
#           DefaultNeuroticism    FrontoparietalNeuroticism   0.0099 0.9789 -0.0142 0.0341  False
#           DefaultNeuroticism             LimbicDepression  -0.0011    1.0 -0.0197 0.0174  False
#           DefaultNeuroticism            LimbicNeuroticism   0.0038    1.0 -0.0148 0.0224  False
#           DefaultNeuroticism        SomatomotorDepression   0.0034    1.0 -0.0139 0.0206  False
#           DefaultNeuroticism       SomatomotorNeuroticism  -0.0014    1.0 -0.0186 0.0159  False
#           DefaultNeuroticism  Ventral AttentionDepression   0.0035    1.0 -0.0143 0.0213  False
#           DefaultNeuroticism Ventral AttentionNeuroticism  -0.0032    1.0 -0.0211 0.0146  False
#           DefaultNeuroticism             VisualDepression  -0.0053 0.9983  -0.022 0.0115  False
#           DefaultNeuroticism            VisualNeuroticism  -0.0022    1.0 -0.0189 0.0146  False
#   Dorsal AttentionDepression  Dorsal AttentionNeuroticism  -0.0174 0.9836 -0.0611 0.0263  False
#   Dorsal AttentionDepression     FrontoparietalDepression   0.0014    1.0 -0.0364 0.0392  False
#   Dorsal AttentionDepression    FrontoparietalNeuroticism   0.0058    1.0 -0.0321 0.0436  False
#   Dorsal AttentionDepression             LimbicDepression  -0.0053    1.0 -0.0398 0.0293  False
#   Dorsal AttentionDepression            LimbicNeuroticism  -0.0003    1.0 -0.0349 0.0342  False
#   Dorsal AttentionDepression        SomatomotorDepression  -0.0008    1.0 -0.0346  0.033  False
#   Dorsal AttentionDepression       SomatomotorNeuroticism  -0.0055    1.0 -0.0394 0.0283  False
#   Dorsal AttentionDepression  Ventral AttentionDepression  -0.0006    1.0 -0.0348 0.0335  False
#   Dorsal AttentionDepression Ventral AttentionNeuroticism  -0.0074    1.0 -0.0415 0.0268  False
#   Dorsal AttentionDepression             VisualDepression  -0.0094 0.9995  -0.043 0.0242  False
#   Dorsal AttentionDepression            VisualNeuroticism  -0.0063    1.0 -0.0399 0.0273  False
#  Dorsal AttentionNeuroticism     FrontoparietalDepression   0.0188  0.909  -0.019 0.0567  False
#  Dorsal AttentionNeuroticism    FrontoparietalNeuroticism   0.0232  0.697 -0.0146  0.061  False
#  Dorsal AttentionNeuroticism             LimbicDepression   0.0121 0.9948 -0.0224 0.0467  False
#  Dorsal AttentionNeuroticism            LimbicNeuroticism   0.0171 0.9129 -0.0175 0.0516  False
#  Dorsal AttentionNeuroticism        SomatomotorDepression   0.0166 0.9162 -0.0172 0.0505  False
#  Dorsal AttentionNeuroticism       SomatomotorNeuroticism   0.0119 0.9947 -0.0219 0.0457  False
#  Dorsal AttentionNeuroticism  Ventral AttentionDepression   0.0168 0.9168 -0.0174 0.0509  False
#  Dorsal AttentionNeuroticism Ventral AttentionNeuroticism   0.0101 0.9991 -0.0241 0.0442  False
#  Dorsal AttentionNeuroticism             VisualDepression    0.008 0.9999 -0.0256 0.0416  False
#  Dorsal AttentionNeuroticism            VisualNeuroticism   0.0111 0.9971 -0.0225 0.0447  False
#     FrontoparietalDepression    FrontoparietalNeuroticism   0.0044    1.0 -0.0265 0.0353  False
#     FrontoparietalDepression             LimbicDepression  -0.0067 0.9998 -0.0334 0.0201  False
#     FrontoparietalDepression            LimbicNeuroticism  -0.0017    1.0 -0.0285  0.025  False
#     FrontoparietalDepression        SomatomotorDepression  -0.0022    1.0  -0.028 0.0237  False
#     FrontoparietalDepression       SomatomotorNeuroticism  -0.0069 0.9997 -0.0328 0.0189  False
#     FrontoparietalDepression  Ventral AttentionDepression  -0.0021    1.0 -0.0283 0.0242  False
#     FrontoparietalDepression Ventral AttentionNeuroticism  -0.0088 0.9968  -0.035 0.0175  False
#     FrontoparietalDepression             VisualDepression  -0.0108 0.9728 -0.0363 0.0147  False
#     FrontoparietalDepression            VisualNeuroticism  -0.0077 0.9988 -0.0332 0.0178  False
#    FrontoparietalNeuroticism             LimbicDepression  -0.0111 0.9778 -0.0378 0.0157  False
#    FrontoparietalNeuroticism            LimbicNeuroticism  -0.0061 0.9999 -0.0329 0.0206  False
#    FrontoparietalNeuroticism        SomatomotorDepression  -0.0066 0.9998 -0.0324 0.0193  False
#    FrontoparietalNeuroticism       SomatomotorNeuroticism  -0.0113  0.965 -0.0371 0.0145  False
#    FrontoparietalNeuroticism  Ventral AttentionDepression  -0.0064 0.9999 -0.0327 0.0198  False
#    FrontoparietalNeuroticism Ventral AttentionNeuroticism  -0.0132 0.9048 -0.0394 0.0131  False
#    FrontoparietalNeuroticism             VisualDepression  -0.0152 0.7381 -0.0407 0.0103  False
#    FrontoparietalNeuroticism            VisualNeuroticism  -0.0121 0.9359 -0.0376 0.0134  False
#             LimbicDepression            LimbicNeuroticism   0.0049    1.0 -0.0169 0.0268  False
#             LimbicDepression        SomatomotorDepression   0.0045    1.0 -0.0162 0.0252  False
#             LimbicDepression       SomatomotorNeuroticism  -0.0002    1.0  -0.021 0.0205  False
#             LimbicDepression  Ventral AttentionDepression   0.0046    1.0 -0.0166 0.0259  False
#             LimbicDepression Ventral AttentionNeuroticism  -0.0021    1.0 -0.0233 0.0191  False
#             LimbicDepression             VisualDepression  -0.0041    1.0 -0.0244 0.0162  False
#             LimbicDepression            VisualNeuroticism   -0.001    1.0 -0.0213 0.0193  False
#            LimbicNeuroticism        SomatomotorDepression  -0.0004    1.0 -0.0212 0.0203  False
#            LimbicNeuroticism       SomatomotorNeuroticism  -0.0052 0.9998 -0.0259 0.0155  False
#            LimbicNeuroticism  Ventral AttentionDepression  -0.0003    1.0 -0.0215 0.0209  False
#            LimbicNeuroticism Ventral AttentionNeuroticism   -0.007 0.9971 -0.0283 0.0142  False
#            LimbicNeuroticism             VisualDepression  -0.0091  0.959 -0.0294 0.0112  False
#            LimbicNeuroticism            VisualNeuroticism   -0.006 0.9991 -0.0263 0.0143  False
#        SomatomotorDepression       SomatomotorNeuroticism  -0.0047 0.9999 -0.0243 0.0148  False
#        SomatomotorDepression  Ventral AttentionDepression   0.0001    1.0 -0.0199 0.0202  False
#        SomatomotorDepression Ventral AttentionNeuroticism  -0.0066 0.9973 -0.0267 0.0135  False
#        SomatomotorDepression             VisualDepression  -0.0086 0.9551 -0.0277 0.0105  False
#        SomatomotorDepression            VisualNeuroticism  -0.0055 0.9993 -0.0246 0.0136  False
#       SomatomotorNeuroticism  Ventral AttentionDepression   0.0049 0.9999 -0.0152 0.0249  False
#       SomatomotorNeuroticism Ventral AttentionNeuroticism  -0.0019    1.0 -0.0219 0.0182  False
#       SomatomotorNeuroticism             VisualDepression  -0.0039    1.0  -0.023 0.0152  False
#       SomatomotorNeuroticism            VisualNeuroticism  -0.0008    1.0 -0.0199 0.0183  False
#  Ventral AttentionDepression Ventral AttentionNeuroticism  -0.0067 0.9975 -0.0273 0.0139  False
#  Ventral AttentionDepression             VisualDepression  -0.0088 0.9592 -0.0284 0.0109  False
#  Ventral AttentionDepression            VisualNeuroticism  -0.0056 0.9993 -0.0253  0.014  False
# Ventral AttentionNeuroticism             VisualDepression   -0.002    1.0 -0.0217 0.0176  False
# Ventral AttentionNeuroticism            VisualNeuroticism   0.0011    1.0 -0.0186 0.0207  False
#             VisualDepression            VisualNeuroticism   0.0031    1.0 -0.0155 0.0217  False
# -----------------------------------------------------------------------------------------------
#
#
#  Two-Way ANOVA with Yeo_name and phen_group on Cortical Thickness results - absolute value
#
#
#                              sum_sq     df         F    PR(>F)
# C(phen_group)              0.000003    1.0  0.095432  0.757967
# C(Yeo_name)                0.000284    6.0  1.446734  0.203392
# C(phen_group):C(Yeo_name)  0.000141    6.0  0.720007  0.634305
# Residual                   0.003596  110.0       NaN       NaN
#
#
#  Post Hoc for Yeo_name - absolute value
#
#
#            Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================
#       group1            group2      meandiff p-adj   lower  upper  reject
# -------------------------------------------------------------------------
#           Default  Dorsal Attention  -0.0029 0.9567 -0.0119  0.006  False
#           Default    Frontoparietal  -0.0025 0.9109 -0.0092 0.0041  False
#           Default            Limbic   0.0018 0.9334 -0.0033 0.0069  False
#           Default       Somatomotor  -0.0009 0.9979 -0.0056 0.0039  False
#           Default Ventral Attention  -0.0032   0.45 -0.0081 0.0017  False
#           Default            Visual  -0.0013 0.9801 -0.0059 0.0033  False
#  Dorsal Attention    Frontoparietal   0.0004    1.0   -0.01 0.0108  False
#  Dorsal Attention            Limbic   0.0048 0.7405 -0.0047 0.0142  False
#  Dorsal Attention       Somatomotor   0.0021 0.9942 -0.0072 0.0114  False
#  Dorsal Attention Ventral Attention  -0.0003    1.0 -0.0096 0.0091  False
#  Dorsal Attention            Visual   0.0016 0.9983 -0.0076 0.0109  False
#    Frontoparietal            Limbic   0.0044 0.5602  -0.003 0.0117  False
#    Frontoparietal       Somatomotor   0.0017 0.9919 -0.0054 0.0088  False
#    Frontoparietal Ventral Attention  -0.0006    1.0 -0.0079 0.0066  False
#    Frontoparietal            Visual   0.0013 0.9982 -0.0057 0.0083  False
#            Limbic       Somatomotor  -0.0027  0.788 -0.0084  0.003  False
#            Limbic Ventral Attention   -0.005 0.1406 -0.0108 0.0008  False
#            Limbic            Visual  -0.0031 0.6322 -0.0087 0.0025  False
#       Somatomotor Ventral Attention  -0.0023 0.8675 -0.0078 0.0032  False
#       Somatomotor            Visual  -0.0004    1.0 -0.0057 0.0048  False
# Ventral Attention            Visual   0.0019 0.9387 -0.0035 0.0073  False
# -------------------------------------------------------------------------
#
#
#  Post Hoc for phen_group - absolute value
#
#
#     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ============================================================
#   group1      group2   meandiff p-adj   lower  upper  reject
# ------------------------------------------------------------
# Depression Neuroticism   0.0003 0.7589 -0.0017 0.0024  False
# ------------------------------------------------------------
#
#
#  Post Hoc for phen_group - absolute value
#
#
#                       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================================================
#            group1                       group2            meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------------
#            DefaultDepression           DefaultNeuroticism   0.0007    1.0 -0.0058 0.0073  False
#            DefaultDepression   Dorsal AttentionDepression  -0.0045 0.9986 -0.0191 0.0101  False
#            DefaultDepression  Dorsal AttentionNeuroticism  -0.0006    1.0 -0.0152  0.014  False
#            DefaultDepression     FrontoparietalDepression  -0.0037 0.9963 -0.0145 0.0072  False
#            DefaultDepression    FrontoparietalNeuroticism  -0.0007    1.0 -0.0115 0.0102  False
#            DefaultDepression             LimbicDepression   0.0034 0.9814  -0.005 0.0117  False
#            DefaultDepression            LimbicNeuroticism    0.001    1.0 -0.0073 0.0094  False
#            DefaultDepression        SomatomotorDepression   0.0007    1.0 -0.0071 0.0084  False
#            DefaultDepression       SomatomotorNeuroticism  -0.0016    1.0 -0.0094 0.0061  False
#            DefaultDepression  Ventral AttentionDepression  -0.0024 0.9987 -0.0105 0.0056  False
#            DefaultDepression Ventral AttentionNeuroticism  -0.0032  0.984 -0.0112 0.0048  False
#            DefaultDepression             VisualDepression  -0.0025 0.9969   -0.01  0.005  False
#            DefaultDepression            VisualNeuroticism   0.0007    1.0 -0.0068 0.0082  False
#           DefaultNeuroticism   Dorsal AttentionDepression  -0.0052 0.9937 -0.0199 0.0094  False
#           DefaultNeuroticism  Dorsal AttentionNeuroticism  -0.0014    1.0  -0.016 0.0133  False
#           DefaultNeuroticism     FrontoparietalDepression  -0.0044 0.9802 -0.0153 0.0064  False
#           DefaultNeuroticism    FrontoparietalNeuroticism  -0.0014    1.0 -0.0122 0.0094  False
#           DefaultNeuroticism             LimbicDepression   0.0026 0.9982 -0.0057  0.011  False
#           DefaultNeuroticism            LimbicNeuroticism   0.0003    1.0  -0.008 0.0086  False
#           DefaultNeuroticism        SomatomotorDepression  -0.0001    1.0 -0.0078 0.0076  False
#           DefaultNeuroticism       SomatomotorNeuroticism  -0.0024 0.9985 -0.0101 0.0053  False
#           DefaultNeuroticism  Ventral AttentionDepression  -0.0032 0.9837 -0.0112 0.0048  False
#           DefaultNeuroticism Ventral AttentionNeuroticism  -0.0039 0.9178 -0.0119 0.0041  False
#           DefaultNeuroticism             VisualDepression  -0.0032 0.9682 -0.0107 0.0043  False
#           DefaultNeuroticism            VisualNeuroticism  -0.0001    1.0 -0.0076 0.0074  False
#   Dorsal AttentionDepression  Dorsal AttentionNeuroticism   0.0039    1.0 -0.0157 0.0235  False
#   Dorsal AttentionDepression     FrontoparietalDepression   0.0008    1.0 -0.0162 0.0178  False
#   Dorsal AttentionDepression    FrontoparietalNeuroticism   0.0038    1.0 -0.0131 0.0208  False
#   Dorsal AttentionDepression             LimbicDepression   0.0079 0.8962 -0.0076 0.0234  False
#   Dorsal AttentionDepression            LimbicNeuroticism   0.0055  0.994   -0.01  0.021  False
#   Dorsal AttentionDepression        SomatomotorDepression   0.0052 0.9963   -0.01 0.0203  False
#   Dorsal AttentionDepression       SomatomotorNeuroticism   0.0028    1.0 -0.0123  0.018  False
#   Dorsal AttentionDepression  Ventral AttentionDepression    0.002    1.0 -0.0133 0.0174  False
#   Dorsal AttentionDepression Ventral AttentionNeuroticism   0.0013    1.0  -0.014 0.0166  False
#   Dorsal AttentionDepression             VisualDepression    0.002    1.0 -0.0131 0.0171  False
#   Dorsal AttentionDepression            VisualNeuroticism   0.0052 0.9959 -0.0099 0.0202  False
#  Dorsal AttentionNeuroticism     FrontoparietalDepression  -0.0031    1.0   -0.02 0.0139  False
#  Dorsal AttentionNeuroticism    FrontoparietalNeuroticism     -0.0    1.0  -0.017 0.0169  False
#  Dorsal AttentionNeuroticism             LimbicDepression    0.004 0.9998 -0.0115 0.0195  False
#  Dorsal AttentionNeuroticism            LimbicNeuroticism   0.0017    1.0 -0.0139 0.0172  False
#  Dorsal AttentionNeuroticism        SomatomotorDepression   0.0013    1.0 -0.0139 0.0165  False
#  Dorsal AttentionNeuroticism       SomatomotorNeuroticism   -0.001    1.0 -0.0162 0.0142  False
#  Dorsal AttentionNeuroticism  Ventral AttentionDepression  -0.0018    1.0 -0.0172 0.0135  False
#  Dorsal AttentionNeuroticism Ventral AttentionNeuroticism  -0.0026    1.0 -0.0179 0.0128  False
#  Dorsal AttentionNeuroticism             VisualDepression  -0.0019    1.0  -0.017 0.0132  False
#  Dorsal AttentionNeuroticism            VisualNeuroticism   0.0013    1.0 -0.0138 0.0164  False
#     FrontoparietalDepression    FrontoparietalNeuroticism    0.003    1.0 -0.0109 0.0169  False
#     FrontoparietalDepression             LimbicDepression   0.0071 0.7556  -0.005 0.0191  False
#     FrontoparietalDepression            LimbicNeuroticism   0.0047 0.9859 -0.0073 0.0167  False
#     FrontoparietalDepression        SomatomotorDepression   0.0043 0.9909 -0.0073 0.0159  False
#     FrontoparietalDepression       SomatomotorNeuroticism    0.002    1.0 -0.0096 0.0136  False
#     FrontoparietalDepression  Ventral AttentionDepression   0.0012    1.0 -0.0106  0.013  False
#     FrontoparietalDepression Ventral AttentionNeuroticism   0.0005    1.0 -0.0113 0.0123  False
#     FrontoparietalDepression             VisualDepression   0.0012    1.0 -0.0103 0.0126  False
#     FrontoparietalDepression            VisualNeuroticism   0.0043 0.9894 -0.0071 0.0158  False
#    FrontoparietalNeuroticism             LimbicDepression    0.004 0.9966  -0.008  0.016  False
#    FrontoparietalNeuroticism            LimbicNeuroticism   0.0017    1.0 -0.0103 0.0137  False
#    FrontoparietalNeuroticism        SomatomotorDepression   0.0013    1.0 -0.0103 0.0129  False
#    FrontoparietalNeuroticism       SomatomotorNeuroticism   -0.001    1.0 -0.0126 0.0106  False
#    FrontoparietalNeuroticism  Ventral AttentionDepression  -0.0018    1.0 -0.0136   0.01  False
#    FrontoparietalNeuroticism Ventral AttentionNeuroticism  -0.0025    1.0 -0.0143 0.0093  False
#    FrontoparietalNeuroticism             VisualDepression  -0.0018    1.0 -0.0133 0.0096  False
#    FrontoparietalNeuroticism            VisualNeuroticism   0.0013    1.0 -0.0101 0.0128  False
#             LimbicDepression            LimbicNeuroticism  -0.0023 0.9999 -0.0121 0.0075  False
#             LimbicDepression        SomatomotorDepression  -0.0027 0.9992  -0.012 0.0066  False
#             LimbicDepression       SomatomotorNeuroticism   -0.005 0.8469 -0.0143 0.0043  False
#             LimbicDepression  Ventral AttentionDepression  -0.0058 0.7025 -0.0154 0.0037  False
#             LimbicDepression Ventral AttentionNeuroticism  -0.0066 0.5153 -0.0161  0.003  False
#             LimbicDepression             VisualDepression  -0.0059 0.6227  -0.015 0.0032  False
#             LimbicDepression            VisualNeuroticism  -0.0027  0.999 -0.0118 0.0064  False
#            LimbicNeuroticism        SomatomotorDepression  -0.0004    1.0 -0.0097 0.0089  False
#            LimbicNeuroticism       SomatomotorNeuroticism  -0.0027 0.9993  -0.012 0.0066  False
#            LimbicNeuroticism  Ventral AttentionDepression  -0.0035 0.9926  -0.013  0.006  False
#            LimbicNeuroticism Ventral AttentionNeuroticism  -0.0042 0.9616 -0.0137 0.0053  False
#            LimbicNeuroticism             VisualDepression  -0.0035 0.9873 -0.0126 0.0056  False
#            LimbicNeuroticism            VisualNeuroticism  -0.0004    1.0 -0.0095 0.0088  False
#        SomatomotorDepression       SomatomotorNeuroticism  -0.0023 0.9997 -0.0111 0.0065  False
#        SomatomotorDepression  Ventral AttentionDepression  -0.0031 0.9957 -0.0121 0.0059  False
#        SomatomotorDepression Ventral AttentionNeuroticism  -0.0038 0.9716 -0.0128 0.0052  False
#        SomatomotorDepression             VisualDepression  -0.0032  0.992 -0.0117 0.0054  False
#        SomatomotorDepression            VisualNeuroticism      0.0    1.0 -0.0086 0.0086  False
#       SomatomotorNeuroticism  Ventral AttentionDepression  -0.0008    1.0 -0.0098 0.0082  False
#       SomatomotorNeuroticism Ventral AttentionNeuroticism  -0.0015    1.0 -0.0105 0.0075  False
#       SomatomotorNeuroticism             VisualDepression  -0.0009    1.0 -0.0094 0.0077  False
#       SomatomotorNeuroticism            VisualNeuroticism   0.0023 0.9996 -0.0062 0.0109  False
#  Ventral AttentionDepression Ventral AttentionNeuroticism  -0.0007    1.0   -0.01 0.0085  False
#  Ventral AttentionDepression             VisualDepression  -0.0001    1.0 -0.0089 0.0088  False
#  Ventral AttentionDepression            VisualNeuroticism   0.0031 0.9944 -0.0057 0.0119  False
# Ventral AttentionNeuroticism             VisualDepression   0.0007    1.0 -0.0081 0.0095  False
# Ventral AttentionNeuroticism            VisualNeuroticism   0.0039 0.9649  -0.005 0.0127  False
#             VisualDepression            VisualNeuroticism   0.0032 0.9895 -0.0052 0.0115  False
# -----------------------------------------------------------------------------------------------
#
#
#  Two-Way ANOVA with Yeo_name and phen_group on Partial Netmats (Schaefer) results - absolute value
#
#
#                              sum_sq       df          F    PR(>F)
# C(phen_group)              0.000297      1.0  13.482238  0.000241
# C(Yeo_name)                0.000212      6.0   1.598695  0.142925
# C(phen_group):C(Yeo_name)  0.000180      6.0   1.362532  0.225560
# Residual                   1.978340  89686.0        NaN       NaN
#
#
#  Post Hoc for Yeo_name - absolute value
#
#
#            Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================
#       group1            group2      meandiff p-adj   lower  upper  reject
# -------------------------------------------------------------------------
#           Default  Dorsal Attention   0.0001 0.8994 -0.0001 0.0003  False
#           Default    Frontoparietal   0.0001 0.9789 -0.0001 0.0002  False
#           Default            Limbic   0.0002 0.2171    -0.0 0.0004  False
#           Default       Somatomotor      0.0    1.0 -0.0001 0.0002  False
#           Default Ventral Attention     -0.0 0.9991 -0.0002 0.0002  False
#           Default            Visual      0.0    1.0 -0.0002 0.0002  False
#  Dorsal Attention    Frontoparietal     -0.0 0.9999 -0.0002 0.0002  False
#  Dorsal Attention            Limbic   0.0001 0.8559 -0.0001 0.0003  False
#  Dorsal Attention       Somatomotor  -0.0001 0.9328 -0.0002 0.0001  False
#  Dorsal Attention Ventral Attention  -0.0001 0.7154 -0.0003 0.0001  False
#  Dorsal Attention            Visual  -0.0001 0.8797 -0.0002 0.0001  False
#    Frontoparietal            Limbic   0.0001 0.7252 -0.0001 0.0004  False
#    Frontoparietal       Somatomotor     -0.0 0.9911 -0.0002 0.0001  False
#    Frontoparietal Ventral Attention  -0.0001 0.8798 -0.0003 0.0001  False
#    Frontoparietal            Visual  -0.0001 0.9755 -0.0002 0.0001  False
#            Limbic       Somatomotor  -0.0002 0.2302 -0.0004    0.0  False
#            Limbic Ventral Attention  -0.0002 0.1208 -0.0004    0.0  False
#            Limbic            Visual  -0.0002 0.1799 -0.0004    0.0  False
#       Somatomotor Ventral Attention     -0.0  0.991 -0.0002 0.0001  False
#       Somatomotor            Visual     -0.0    1.0 -0.0001 0.0001  False
# Ventral Attention            Visual      0.0  0.998 -0.0001 0.0002  False
# -------------------------------------------------------------------------
#
#
#  Post Hoc for phen_group - absolute value
#
#
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =============================================================
#   group1      group2   meandiff p-adj   lower   upper  reject
# -------------------------------------------------------------
# Depression Neuroticism  -0.0001 0.0002 -0.0002 -0.0001   True
# -------------------------------------------------------------
#
#
#  Post Hoc for phen_group - absolute value
#
#
#                       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================================================================
#            group1                       group2            meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------------------------------------
#            DefaultDepression           DefaultNeuroticism  -0.0001 0.8939 -0.0004  0.0001  False
#            DefaultDepression   Dorsal AttentionDepression      0.0    1.0 -0.0002  0.0003  False
#            DefaultDepression  Dorsal AttentionNeuroticism     -0.0    1.0 -0.0003  0.0003  False
#            DefaultDepression     FrontoparietalDepression      0.0    1.0 -0.0003  0.0003  False
#            DefaultDepression    FrontoparietalNeuroticism  -0.0001 0.9999 -0.0004  0.0002  False
#            DefaultDepression             LimbicDepression   0.0003 0.3653 -0.0001  0.0006  False
#            DefaultDepression            LimbicNeuroticism  -0.0001    1.0 -0.0004  0.0003  False
#            DefaultDepression        SomatomotorDepression      0.0    1.0 -0.0002  0.0003  False
#            DefaultDepression       SomatomotorNeuroticism  -0.0001 0.9142 -0.0004  0.0001  False
#            DefaultDepression  Ventral AttentionDepression      0.0    1.0 -0.0003  0.0003  False
#            DefaultDepression Ventral AttentionNeuroticism  -0.0002 0.5185 -0.0005  0.0001  False
#            DefaultDepression             VisualDepression  -0.0001 0.9989 -0.0003  0.0002  False
#            DefaultDepression            VisualNeuroticism  -0.0001 0.9999 -0.0003  0.0002  False
#           DefaultNeuroticism   Dorsal AttentionDepression   0.0002 0.6488 -0.0001  0.0005  False
#           DefaultNeuroticism  Dorsal AttentionNeuroticism   0.0001 0.9978 -0.0002  0.0004  False
#           DefaultNeuroticism     FrontoparietalDepression   0.0002  0.744 -0.0001  0.0005  False
#           DefaultNeuroticism    FrontoparietalNeuroticism   0.0001    1.0 -0.0002  0.0004  False
#           DefaultNeuroticism             LimbicDepression   0.0004 0.0067  0.0001  0.0008   True
#           DefaultNeuroticism            LimbicNeuroticism   0.0001    1.0 -0.0003  0.0004  False
#           DefaultNeuroticism        SomatomotorDepression   0.0001 0.7502 -0.0001  0.0004  False
#           DefaultNeuroticism       SomatomotorNeuroticism      0.0    1.0 -0.0002  0.0003  False
#           DefaultNeuroticism  Ventral AttentionDepression   0.0001 0.9267 -0.0001  0.0004  False
#           DefaultNeuroticism Ventral AttentionNeuroticism  -0.0001    1.0 -0.0004  0.0002  False
#           DefaultNeuroticism             VisualDepression   0.0001 0.9999 -0.0002  0.0003  False
#           DefaultNeuroticism            VisualNeuroticism   0.0001 0.9981 -0.0002  0.0003  False
#   Dorsal AttentionDepression  Dorsal AttentionNeuroticism  -0.0001 0.9995 -0.0004  0.0002  False
#   Dorsal AttentionDepression     FrontoparietalDepression     -0.0    1.0 -0.0003  0.0003  False
#   Dorsal AttentionDepression    FrontoparietalNeuroticism  -0.0001 0.9919 -0.0004  0.0002  False
#   Dorsal AttentionDepression             LimbicDepression   0.0002 0.7746 -0.0001  0.0006  False
#   Dorsal AttentionDepression            LimbicNeuroticism  -0.0001 0.9993 -0.0005  0.0003  False
#   Dorsal AttentionDepression        SomatomotorDepression     -0.0    1.0 -0.0003  0.0002  False
#   Dorsal AttentionDepression       SomatomotorNeuroticism  -0.0002 0.6683 -0.0004  0.0001  False
#   Dorsal AttentionDepression  Ventral AttentionDepression     -0.0    1.0 -0.0004  0.0003  False
#   Dorsal AttentionDepression Ventral AttentionNeuroticism  -0.0003 0.2773 -0.0006  0.0001  False
#   Dorsal AttentionDepression             VisualDepression  -0.0001 0.9591 -0.0004  0.0001  False
#   Dorsal AttentionDepression            VisualNeuroticism  -0.0001 0.9886 -0.0004  0.0002  False
#  Dorsal AttentionNeuroticism     FrontoparietalDepression   0.0001 0.9999 -0.0002  0.0004  False
#  Dorsal AttentionNeuroticism    FrontoparietalNeuroticism     -0.0    1.0 -0.0003  0.0003  False
#  Dorsal AttentionNeuroticism             LimbicDepression   0.0003 0.2103 -0.0001  0.0007  False
#  Dorsal AttentionNeuroticism            LimbicNeuroticism     -0.0    1.0 -0.0004  0.0004  False
#  Dorsal AttentionNeuroticism        SomatomotorDepression      0.0    1.0 -0.0002  0.0003  False
#  Dorsal AttentionNeuroticism       SomatomotorNeuroticism  -0.0001 0.9993 -0.0004  0.0002  False
#  Dorsal AttentionNeuroticism  Ventral AttentionDepression      0.0    1.0 -0.0003  0.0004  False
#  Dorsal AttentionNeuroticism Ventral AttentionNeuroticism  -0.0002 0.9067 -0.0005  0.0002  False
#  Dorsal AttentionNeuroticism             VisualDepression     -0.0    1.0 -0.0003  0.0002  False
#  Dorsal AttentionNeuroticism            VisualNeuroticism     -0.0    1.0 -0.0003  0.0003  False
#     FrontoparietalDepression    FrontoparietalNeuroticism  -0.0001 0.9967 -0.0004  0.0002  False
#     FrontoparietalDepression             LimbicDepression   0.0002 0.7314 -0.0001  0.0006  False
#     FrontoparietalDepression            LimbicNeuroticism  -0.0001 0.9998 -0.0005  0.0003  False
#     FrontoparietalDepression        SomatomotorDepression     -0.0    1.0 -0.0003  0.0002  False
#     FrontoparietalDepression       SomatomotorNeuroticism  -0.0002 0.7703 -0.0004  0.0001  False
#     FrontoparietalDepression  Ventral AttentionDepression     -0.0    1.0 -0.0004  0.0003  False
# ...
#     FrontoparietalDepression             VisualDepression  -0.0001 0.9812 -0.0004  0.0002  False
#     FrontoparietalDepression            VisualNeuroticism  -0.0001 0.9958 -0.0004  0.0002  False
#    FrontoparietalNeuroticism             LimbicDepression   0.0003 0.1133    -0.0  0.0007  False
#    FrontoparietalNeuroticism            LimbicNeuroticism      0.0    1.0 -0.0004  0.0004  False
#    FrontoparietalNeuroticism        SomatomotorDepression   0.0001 0.9995 -0.0002  0.0004  False
#    FrontoparietalNeuroticism       SomatomotorNeuroticism  -0.0001    1.0 -0.0003  0.0002  False
#    FrontoparietalNeuroticism  Ventral AttentionDepression   0.0001 0.9999 -0.0002  0.0004  False
#    FrontoparietalNeuroticism Ventral AttentionNeuroticism  -0.0001 0.9832 -0.0005  0.0002  False
#    FrontoparietalNeuroticism             VisualDepression     -0.0    1.0 -0.0003  0.0003  False
#    FrontoparietalNeuroticism            VisualNeuroticism      0.0    1.0 -0.0003  0.0003  False
#             LimbicDepression            LimbicNeuroticism  -0.0003 0.3035 -0.0007  0.0001  False
#             LimbicDepression        SomatomotorDepression  -0.0003 0.3069 -0.0006  0.0001  False
#             LimbicDepression       SomatomotorNeuroticism  -0.0004 0.0054 -0.0007 -0.0001   True
#             LimbicDepression  Ventral AttentionDepression  -0.0003 0.4935 -0.0006  0.0001  False
#             LimbicDepression Ventral AttentionNeuroticism  -0.0005 0.0014 -0.0008 -0.0001   True
#             LimbicDepression             VisualDepression  -0.0003 0.0343 -0.0007    -0.0   True
#             LimbicDepression            VisualNeuroticism  -0.0003 0.0602 -0.0007     0.0  False
#            LimbicNeuroticism        SomatomotorDepression   0.0001    1.0 -0.0003  0.0004  False
#            LimbicNeuroticism       SomatomotorNeuroticism  -0.0001    1.0 -0.0004  0.0003  False
#            LimbicNeuroticism  Ventral AttentionDepression   0.0001    1.0 -0.0003  0.0004  False
#            LimbicNeuroticism Ventral AttentionNeuroticism  -0.0001 0.9895 -0.0005  0.0002  False
#            LimbicNeuroticism             VisualDepression     -0.0    1.0 -0.0003  0.0003  False
#            LimbicNeuroticism            VisualNeuroticism      0.0    1.0 -0.0003  0.0003  False
#        SomatomotorDepression       SomatomotorNeuroticism  -0.0001 0.7499 -0.0003  0.0001  False
#        SomatomotorDepression  Ventral AttentionDepression     -0.0    1.0 -0.0003  0.0003  False
#        SomatomotorDepression Ventral AttentionNeuroticism  -0.0002 0.3239 -0.0005  0.0001  False
#        SomatomotorDepression             VisualDepression  -0.0001 0.9924 -0.0003  0.0001  False
#        SomatomotorDepression            VisualNeuroticism  -0.0001 0.9993 -0.0003  0.0002  False
#       SomatomotorNeuroticism  Ventral AttentionDepression   0.0001 0.9471 -0.0001  0.0004  False
#       SomatomotorNeuroticism Ventral AttentionNeuroticism  -0.0001 0.9992 -0.0004  0.0002  False
#       SomatomotorNeuroticism             VisualDepression      0.0    1.0 -0.0002  0.0003  False
#       SomatomotorNeuroticism            VisualNeuroticism   0.0001 0.9995 -0.0002  0.0003  False
#  Ventral AttentionDepression Ventral AttentionNeuroticism  -0.0002 0.6053 -0.0005  0.0001  False
#  Ventral AttentionDepression             VisualDepression  -0.0001 0.9993 -0.0004  0.0002  False
#  Ventral AttentionDepression            VisualNeuroticism  -0.0001 0.9999 -0.0003  0.0002  False
# Ventral AttentionNeuroticism             VisualDepression   0.0001 0.9534 -0.0001  0.0004  False
# Ventral AttentionNeuroticism            VisualNeuroticism   0.0001 0.8828 -0.0001  0.0004  False
#             VisualDepression            VisualNeuroticism      0.0    1.0 -0.0002  0.0002  False
# ------------------------------------------------------------------------------------------------
#
#
#  Two-Way ANOVA with Yeo_name and phen_group on Full Netmats (Schaefer) results - absolute value
#
#
#                              sum_sq       df           F         PR(>F)
# C(phen_group)              0.019156      1.0  397.802986   2.577324e-88
# C(Yeo_name)                0.096367      6.0  333.533627   0.000000e+00
# C(phen_group):C(Yeo_name)  0.027431      6.0   94.941342  1.992421e-119
# Residual                   4.318799  89686.0         NaN            NaN
#
#
#  Post Hoc for Yeo_name - absolute value
#
#
#            Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==========================================================================
#       group1            group2      meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------------------
#           Default  Dorsal Attention   0.0022    0.0  0.0019  0.0025   True
#           Default    Frontoparietal   0.0005    0.0  0.0002  0.0008   True
#           Default            Limbic   0.0003 0.1319    -0.0  0.0006  False
#           Default       Somatomotor   0.0029    0.0  0.0026  0.0031   True
#           Default Ventral Attention   0.0021    0.0  0.0018  0.0024   True
#           Default            Visual   0.0017    0.0  0.0014  0.0019   True
#  Dorsal Attention    Frontoparietal  -0.0017    0.0  -0.002 -0.0014   True
#  Dorsal Attention            Limbic  -0.0019    0.0 -0.0023 -0.0016   True
#  Dorsal Attention       Somatomotor   0.0007    0.0  0.0004  0.0009   True
#  Dorsal Attention Ventral Attention  -0.0001  0.938 -0.0004  0.0002  False
#  Dorsal Attention            Visual  -0.0005    0.0 -0.0008 -0.0003   True
#    Frontoparietal            Limbic  -0.0002 0.5345 -0.0006  0.0001  False
#    Frontoparietal       Somatomotor   0.0024    0.0  0.0021  0.0026   True
#    Frontoparietal Ventral Attention   0.0016    0.0  0.0013  0.0019   True
#    Frontoparietal            Visual   0.0012    0.0  0.0009  0.0014   True
#            Limbic       Somatomotor   0.0026    0.0  0.0023  0.0029   True
#            Limbic Ventral Attention   0.0018    0.0  0.0015  0.0021   True
#            Limbic            Visual   0.0014    0.0  0.0011  0.0017   True
#       Somatomotor Ventral Attention  -0.0008    0.0  -0.001 -0.0005   True
#       Somatomotor            Visual  -0.0012    0.0 -0.0014  -0.001   True
# Ventral Attention            Visual  -0.0004    0.0 -0.0007 -0.0002   True
# --------------------------------------------------------------------------
#
#
#  Post Hoc for phen_group - absolute value
#
#
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================
#   group1      group2   meandiff p-adj lower  upper reject
# ---------------------------------------------------------
# Depression Neuroticism   0.0009   0.0 0.0008 0.001   True
# ---------------------------------------------------------
#
#
#  Post Hoc for phen_group - absolute value
#
#
#                       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================================================================
#            group1                       group2            meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------------------------------------
#            DefaultDepression           DefaultNeuroticism  -0.0006    0.0  -0.001 -0.0002   True
#            DefaultDepression   Dorsal AttentionDepression    0.002    0.0  0.0015  0.0024   True
#            DefaultDepression  Dorsal AttentionNeuroticism   0.0018    0.0  0.0014  0.0022   True
#            DefaultDepression     FrontoparietalDepression      0.0    1.0 -0.0004  0.0005  False
#            DefaultDepression    FrontoparietalNeuroticism   0.0003 0.3549 -0.0001  0.0008  False
#            DefaultDepression             LimbicDepression  -0.0005 0.0271 -0.0011    -0.0   True
#            DefaultDepression            LimbicNeuroticism   0.0005  0.099    -0.0   0.001  False
#            DefaultDepression        SomatomotorDepression   0.0015    0.0  0.0011  0.0018   True
#            DefaultDepression       SomatomotorNeuroticism   0.0036    0.0  0.0033   0.004   True
#            DefaultDepression  Ventral AttentionDepression   0.0018    0.0  0.0013  0.0022   True
#            DefaultDepression Ventral AttentionNeuroticism   0.0018    0.0  0.0013  0.0022   True
#            DefaultDepression             VisualDepression   0.0004 0.0272     0.0  0.0008   True
#            DefaultDepression            VisualNeuroticism   0.0023    0.0  0.0019  0.0027   True
#           DefaultNeuroticism   Dorsal AttentionDepression   0.0026    0.0  0.0022   0.003   True
#           DefaultNeuroticism  Dorsal AttentionNeuroticism   0.0024    0.0   0.002  0.0029   True
#           DefaultNeuroticism     FrontoparietalDepression   0.0007 0.0001  0.0002  0.0011   True
#           DefaultNeuroticism    FrontoparietalNeuroticism    0.001    0.0  0.0005  0.0014   True
#           DefaultNeuroticism             LimbicDepression   0.0001    1.0 -0.0004  0.0006  False
#           DefaultNeuroticism            LimbicNeuroticism   0.0011    0.0  0.0006  0.0016   True
#           DefaultNeuroticism        SomatomotorDepression   0.0021    0.0  0.0017  0.0024   True
#           DefaultNeuroticism       SomatomotorNeuroticism   0.0043    0.0  0.0039  0.0046   True
#           DefaultNeuroticism  Ventral AttentionDepression   0.0024    0.0   0.002  0.0028   True
#           DefaultNeuroticism Ventral AttentionNeuroticism   0.0024    0.0   0.002  0.0028   True
#           DefaultNeuroticism             VisualDepression    0.001    0.0  0.0007  0.0014   True
#           DefaultNeuroticism            VisualNeuroticism   0.0029    0.0  0.0026  0.0033   True
#   Dorsal AttentionDepression  Dorsal AttentionNeuroticism  -0.0002 0.9897 -0.0006  0.0003  False
#   Dorsal AttentionDepression     FrontoparietalDepression   -0.002    0.0 -0.0024 -0.0015   True
#   Dorsal AttentionDepression    FrontoparietalNeuroticism  -0.0016    0.0 -0.0021 -0.0012   True
#   Dorsal AttentionDepression             LimbicDepression  -0.0025    0.0 -0.0031  -0.002   True
#   Dorsal AttentionDepression            LimbicNeuroticism  -0.0015    0.0  -0.002 -0.0009   True
#   Dorsal AttentionDepression        SomatomotorDepression  -0.0005 0.0012 -0.0009 -0.0001   True
#   Dorsal AttentionDepression       SomatomotorNeuroticism   0.0017    0.0  0.0013  0.0021   True
#   Dorsal AttentionDepression  Ventral AttentionDepression  -0.0002 0.9752 -0.0007  0.0003  False
#   Dorsal AttentionDepression Ventral AttentionNeuroticism  -0.0002 0.9849 -0.0007  0.0003  False
#   Dorsal AttentionDepression             VisualDepression  -0.0016    0.0  -0.002 -0.0012   True
#   Dorsal AttentionDepression            VisualNeuroticism   0.0003 0.3082 -0.0001  0.0007  False
#  Dorsal AttentionNeuroticism     FrontoparietalDepression  -0.0018    0.0 -0.0022 -0.0013   True
#  Dorsal AttentionNeuroticism    FrontoparietalNeuroticism  -0.0015    0.0 -0.0019  -0.001   True
#  Dorsal AttentionNeuroticism             LimbicDepression  -0.0023    0.0 -0.0029 -0.0018   True
#  Dorsal AttentionNeuroticism            LimbicNeuroticism  -0.0013    0.0 -0.0019 -0.0008   True
#  Dorsal AttentionNeuroticism        SomatomotorDepression  -0.0003 0.2214 -0.0007  0.0001  False
#  Dorsal AttentionNeuroticism       SomatomotorNeuroticism   0.0019    0.0  0.0015  0.0023   True
#  Dorsal AttentionNeuroticism  Ventral AttentionDepression     -0.0    1.0 -0.0005  0.0004  False
#  Dorsal AttentionNeuroticism Ventral AttentionNeuroticism     -0.0    1.0 -0.0005  0.0005  False
#  Dorsal AttentionNeuroticism             VisualDepression  -0.0014    0.0 -0.0018  -0.001   True
#  Dorsal AttentionNeuroticism            VisualNeuroticism   0.0005 0.0025  0.0001  0.0009   True
#     FrontoparietalDepression    FrontoparietalNeuroticism   0.0003 0.6093 -0.0002  0.0008  False
#     FrontoparietalDepression             LimbicDepression  -0.0006 0.0355 -0.0011    -0.0   True
#     FrontoparietalDepression            LimbicNeuroticism   0.0005 0.2187 -0.0001   0.001  False
#     FrontoparietalDepression        SomatomotorDepression   0.0014    0.0   0.001  0.0018   True
#     FrontoparietalDepression       SomatomotorNeuroticism   0.0036    0.0  0.0032   0.004   True
#     FrontoparietalDepression  Ventral AttentionDepression   0.0017    0.0  0.0013  0.0022   True
#     FrontoparietalDepression Ventral AttentionNeuroticism   0.0018    0.0  0.0013  0.0022   True
#     FrontoparietalDepression             VisualDepression   0.0004 0.1426    -0.0  0.0008  False
#     FrontoparietalDepression            VisualNeuroticism   0.0023    0.0  0.0019  0.0027   True
#    FrontoparietalNeuroticism             LimbicDepression  -0.0009    0.0 -0.0014 -0.0003   True
#    FrontoparietalNeuroticism            LimbicNeuroticism   0.0001 0.9999 -0.0004  0.0007  False
#    FrontoparietalNeuroticism        SomatomotorDepression   0.0011    0.0  0.0007  0.0015   True
#    FrontoparietalNeuroticism       SomatomotorNeuroticism   0.0033    0.0  0.0029  0.0037   True
#    FrontoparietalNeuroticism  Ventral AttentionDepression   0.0014    0.0   0.001  0.0019   True
#    FrontoparietalNeuroticism Ventral AttentionNeuroticism   0.0014    0.0   0.001  0.0019   True
#    FrontoparietalNeuroticism             VisualDepression      0.0    1.0 -0.0004  0.0005  False
#    FrontoparietalNeuroticism            VisualNeuroticism    0.002    0.0  0.0015  0.0024   True
#             LimbicDepression            LimbicNeuroticism    0.001    0.0  0.0004  0.0016   True
#             LimbicDepression        SomatomotorDepression    0.002    0.0  0.0015  0.0025   True
#             LimbicDepression       SomatomotorNeuroticism   0.0042    0.0  0.0037  0.0047   True
#             LimbicDepression  Ventral AttentionDepression   0.0023    0.0  0.0018  0.0029   True
#             LimbicDepression Ventral AttentionNeuroticism   0.0023    0.0  0.0018  0.0029   True
#             LimbicDepression             VisualDepression   0.0009    0.0  0.0004  0.0014   True
#             LimbicDepression            VisualNeuroticism   0.0028    0.0  0.0023  0.0033   True
#            LimbicNeuroticism        SomatomotorDepression    0.001    0.0  0.0005  0.0015   True
#            LimbicNeuroticism       SomatomotorNeuroticism   0.0032    0.0  0.0027  0.0036   True
#            LimbicNeuroticism  Ventral AttentionDepression   0.0013    0.0  0.0007  0.0018   True
#            LimbicNeuroticism Ventral AttentionNeuroticism   0.0013    0.0  0.0008  0.0018   True
#            LimbicNeuroticism             VisualDepression  -0.0001    1.0 -0.0006  0.0004  False
#            LimbicNeuroticism            VisualNeuroticism   0.0018    0.0  0.0013  0.0023   True
#        SomatomotorDepression       SomatomotorNeuroticism   0.0022    0.0  0.0019  0.0025   True
#        SomatomotorDepression  Ventral AttentionDepression   0.0003 0.3224 -0.0001  0.0007  False
#        SomatomotorDepression Ventral AttentionNeuroticism   0.0003 0.2655 -0.0001  0.0007  False
#        SomatomotorDepression             VisualDepression  -0.0011    0.0 -0.0014 -0.0007   True
#        SomatomotorDepression            VisualNeuroticism   0.0008    0.0  0.0005  0.0012   True
#       SomatomotorNeuroticism  Ventral AttentionDepression  -0.0019    0.0 -0.0023 -0.0015   True
#       SomatomotorNeuroticism Ventral AttentionNeuroticism  -0.0019    0.0 -0.0023 -0.0015   True
#       SomatomotorNeuroticism             VisualDepression  -0.0033    0.0 -0.0036 -0.0029   True
#       SomatomotorNeuroticism            VisualNeuroticism  -0.0013    0.0 -0.0017  -0.001   True
#  Ventral AttentionDepression Ventral AttentionNeuroticism      0.0    1.0 -0.0005  0.0005  False
#  Ventral AttentionDepression             VisualDepression  -0.0014    0.0 -0.0018  -0.001   True
#  Ventral AttentionDepression            VisualNeuroticism   0.0005 0.0013  0.0001  0.0009   True
# Ventral AttentionNeuroticism             VisualDepression  -0.0014    0.0 -0.0018  -0.001   True
# Ventral AttentionNeuroticism            VisualNeuroticism   0.0005  0.002  0.0001  0.0009   True
#             VisualDepression            VisualNeuroticism   0.0019    0.0  0.0016  0.0022   True
# ------------------------------------------------------------------------------------------------

# %%
### SPATIAL --> 6X main effect of yeo only (with FDR correction) 

# List to store p-values and imaging metrics from ANOVA tests
all_img_metrics = []
p_values = []

# First loop: Collect p-values
for df in all_dfs:
    model = ols("""estimate ~ C(Yeo_name)""", data=df).fit()
    anova_results = sm.stats.anova_lm(model, typ=2)
    img_met = df["imaging_metric"].unique()[0]
    all_img_metrics.append(img_met)

    # Extract the p-value from the ANOVA results
    p_value = anova_results['PR(>F)'][0]
    p_values.append(p_value)

    # Post hoc for Yeo_name
    mc = MultiComparison(df['estimate'], df['Yeo_name'])
    posthoc_results = mc.tukeyhsd()

# Apply FDR correction to the collected p-values
_, corrected_p_values, _, _ = multipletests(p_values, alpha=0.05, method='fdr_bh')

# Second loop: Append FDR-corrected p-values to the ANOVA results and print
corrected_p_index = 0
for df in all_dfs:
    model = ols("""estimate ~ C(Yeo_name)""", data=df).fit()
    anova_results = sm.stats.anova_lm(model, typ=2)
    img_met = df["imaging_metric"].unique()[0]

    # Add a new column for FDR corrected p-values
    anova_results['P_FDR'] = [corrected_p_values[corrected_p_index]] + [None] * (len(anova_results) - 1)
    corrected_p_index += 1

    # Print the anova_results with the new column
    print(f"\n\n One-Way ANOVA with Yeo network on {img_met} results - with FDR correction \n\n")
    print(anova_results)

    # Post hoc for phen_group
    mc = MultiComparison(df['estimate'], df['Yeo_name'])
    posthoc_results = mc.tukeyhsd()
    print("\n\n Post Hoc for Yeo_name - absolute value \n\n")
    print(posthoc_results)
# Out:
# /var/folders/tx/3z8_jq352fd7z_0llwbf29380000gp/T/ipykernel_650/3159170281.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = anova_results['PR(>F)'][0]
# /var/folders/tx/3z8_jq352fd7z_0llwbf29380000gp/T/ipykernel_650/3159170281.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = anova_results['PR(>F)'][0]
# /var/folders/tx/3z8_jq352fd7z_0llwbf29380000gp/T/ipykernel_650/3159170281.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = anova_results['PR(>F)'][0]
# /var/folders/tx/3z8_jq352fd7z_0llwbf29380000gp/T/ipykernel_650/3159170281.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = anova_results['PR(>F)'][0]
# /var/folders/tx/3z8_jq352fd7z_0llwbf29380000gp/T/ipykernel_650/3159170281.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = anova_results['PR(>F)'][0]
#  One-Way ANOVA with Yeo network on Gray Matter Volume results - with FDR correction
#
#
#                sum_sq     df        F        PR(>F)         P_FDR
# C(Yeo_name)  0.008324    7.0  9.30424  1.594013e-09  3.985032e-09
# Residual     0.018915  148.0      NaN           NaN           NaN
#
#
#  Post Hoc for Yeo_name - absolute value
#
#
#            Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==========================================================================
#       group1            group2      meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------------------
#           Default  Dorsal Attention  -0.0108 0.6096 -0.0291  0.0075  False
#           Default    Frontoparietal   0.0038 0.9898 -0.0098  0.0173  False
#           Default            Limbic  -0.0047 0.8642 -0.0151  0.0058  False
#           Default       Somatomotor  -0.0036   0.95 -0.0132  0.0061  False
#           Default       Subcortical  -0.0192    0.0 -0.0277 -0.0108   True
#           Default Ventral Attention  -0.0013 0.9999 -0.0113  0.0088  False
#           Default            Visual  -0.0073 0.2569 -0.0167  0.0021  False
#  Dorsal Attention    Frontoparietal   0.0146 0.4157 -0.0067  0.0359  False
#  Dorsal Attention            Limbic   0.0061 0.9779 -0.0133  0.0256  False
#  Dorsal Attention       Somatomotor   0.0073 0.9379 -0.0118  0.0263  False
#  Dorsal Attention       Subcortical  -0.0084 0.8562 -0.0268    0.01  False
#  Dorsal Attention Ventral Attention   0.0095 0.7911 -0.0097  0.0288  False
#  Dorsal Attention            Visual   0.0035 0.9991 -0.0154  0.0224  False
#    Frontoparietal            Limbic  -0.0084 0.6703 -0.0235  0.0066  False
#    Frontoparietal       Somatomotor  -0.0073 0.7815 -0.0218  0.0072  False
#    Frontoparietal       Subcortical   -0.023    0.0 -0.0367 -0.0092   True
#    Frontoparietal Ventral Attention   -0.005 0.9661 -0.0198  0.0097  False
#    Frontoparietal            Visual  -0.0111 0.2652 -0.0254  0.0033  False
#            Limbic       Somatomotor   0.0011    1.0 -0.0105  0.0128  False
#            Limbic       Subcortical  -0.0145 0.0012 -0.0252 -0.0039   True
#            Limbic Ventral Attention   0.0034 0.9875 -0.0085  0.0154  False
#            Limbic            Visual  -0.0026 0.9969  -0.014  0.0088  False
#       Somatomotor       Subcortical  -0.0157 0.0001 -0.0256 -0.0058   True
#       Somatomotor Ventral Attention   0.0023 0.9986  -0.009  0.0136  False
#       Somatomotor            Visual  -0.0037 0.9617 -0.0145   0.007  False
#       Subcortical Ventral Attention   0.0179    0.0  0.0077  0.0282   True
#       Subcortical            Visual   0.0119 0.0049  0.0023  0.0216   True
# Ventral Attention            Visual   -0.006 0.7036 -0.0171   0.005  False
# --------------------------------------------------------------------------
#
#
#  One-Way ANOVA with Yeo network on Cortical Surface Area results - with FDR correction
#
#
#                sum_sq     df         F    PR(>F)     P_FDR
# C(Yeo_name)  0.001289    6.0  1.308922  0.258584  0.258584
# Residual     0.019196  117.0       NaN       NaN       NaN
#
#
#  Post Hoc for Yeo_name - absolute value
#
#
#            Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================
#       group1            group2      meandiff p-adj   lower  upper  reject
# -------------------------------------------------------------------------
#           Default  Dorsal Attention  -0.0085 0.8708 -0.0287 0.0118  False
#           Default    Frontoparietal   0.0038 0.9877 -0.0112 0.0189  False
#           Default            Limbic  -0.0026 0.9941 -0.0141  0.009  False
#           Default       Somatomotor  -0.0029  0.983 -0.0136 0.0078  False
#           Default Ventral Attention  -0.0038 0.9486 -0.0149 0.0073  False
#           Default            Visual  -0.0076 0.3065  -0.018 0.0028  False
#  Dorsal Attention    Frontoparietal   0.0123 0.7025 -0.0112 0.0358  False
#  Dorsal Attention            Limbic   0.0059  0.982 -0.0156 0.0274  False
#  Dorsal Attention       Somatomotor   0.0056 0.9853 -0.0155 0.0266  False
#  Dorsal Attention Ventral Attention   0.0047 0.9943 -0.0165 0.0259  False
#  Dorsal Attention            Visual   0.0009    1.0   -0.02 0.0218  False
#    Frontoparietal            Limbic  -0.0064 0.9093  -0.023 0.0102  False
#    Frontoparietal       Somatomotor  -0.0067 0.8691 -0.0228 0.0093  False
#    Frontoparietal Ventral Attention  -0.0076 0.8025 -0.0239 0.0087  False
#    Frontoparietal            Visual  -0.0114 0.3234 -0.0273 0.0044  False
#            Limbic       Somatomotor  -0.0003    1.0 -0.0132 0.0125  False
#            Limbic Ventral Attention  -0.0012    1.0 -0.0144  0.012  False
#            Limbic            Visual   -0.005 0.8941 -0.0177 0.0076  False
#       Somatomotor Ventral Attention  -0.0009    1.0 -0.0133 0.0116  False
#       Somatomotor            Visual  -0.0047 0.8978 -0.0166 0.0072  False
# Ventral Attention            Visual  -0.0038 0.9647 -0.0161 0.0084  False
# -------------------------------------------------------------------------
#
#
#  One-Way ANOVA with Yeo network on Cortical Thickness results - with FDR correction
#
#
#                sum_sq     df         F   PR(>F)     P_FDR
# C(Yeo_name)  0.000284    6.0  1.479414  0.19114  0.238925
# Residual     0.003740  117.0       NaN      NaN       NaN
#
#
#  Post Hoc for Yeo_name - absolute value
#
#
#            Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================
#       group1            group2      meandiff p-adj   lower  upper  reject
# -------------------------------------------------------------------------
#           Default  Dorsal Attention  -0.0029 0.9567 -0.0119  0.006  False
#           Default    Frontoparietal  -0.0025 0.9109 -0.0092 0.0041  False
#           Default            Limbic   0.0018 0.9334 -0.0033 0.0069  False
#           Default       Somatomotor  -0.0009 0.9979 -0.0056 0.0039  False
#           Default Ventral Attention  -0.0032   0.45 -0.0081 0.0017  False
#           Default            Visual  -0.0013 0.9801 -0.0059 0.0033  False
#  Dorsal Attention    Frontoparietal   0.0004    1.0   -0.01 0.0108  False
#  Dorsal Attention            Limbic   0.0048 0.7405 -0.0047 0.0142  False
#  Dorsal Attention       Somatomotor   0.0021 0.9942 -0.0072 0.0114  False
#  Dorsal Attention Ventral Attention  -0.0003    1.0 -0.0096 0.0091  False
#  Dorsal Attention            Visual   0.0016 0.9983 -0.0076 0.0109  False
#    Frontoparietal            Limbic   0.0044 0.5602  -0.003 0.0117  False
#    Frontoparietal       Somatomotor   0.0017 0.9919 -0.0054 0.0088  False
#    Frontoparietal Ventral Attention  -0.0006    1.0 -0.0079 0.0066  False
#    Frontoparietal            Visual   0.0013 0.9982 -0.0057 0.0083  False
#            Limbic       Somatomotor  -0.0027  0.788 -0.0084  0.003  False
#            Limbic Ventral Attention   -0.005 0.1406 -0.0108 0.0008  False
#            Limbic            Visual  -0.0031 0.6322 -0.0087 0.0025  False
#       Somatomotor Ventral Attention  -0.0023 0.8675 -0.0078 0.0032  False
#       Somatomotor            Visual  -0.0004    1.0 -0.0057 0.0048  False
# Ventral Attention            Visual   0.0019 0.9387 -0.0035 0.0073  False
# -------------------------------------------------------------------------
#
#
#  One-Way ANOVA with Yeo network on Partial Netmats (Schaefer) results - with FDR correction
#
#
#                sum_sq       df         F    PR(>F)     P_FDR
# C(Yeo_name)  0.000212      6.0  1.598434  0.142999  0.238332
# Residual     1.978818  89693.0       NaN       NaN       NaN
#
#
#  Post Hoc for Yeo_name - absolute value
#
#
#            Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================
#       group1            group2      meandiff p-adj   lower  upper  reject
# -------------------------------------------------------------------------
#           Default  Dorsal Attention   0.0001 0.8994 -0.0001 0.0003  False
#           Default    Frontoparietal   0.0001 0.9789 -0.0001 0.0002  False
#           Default            Limbic   0.0002 0.2171    -0.0 0.0004  False
#           Default       Somatomotor      0.0    1.0 -0.0001 0.0002  False
#           Default Ventral Attention     -0.0 0.9991 -0.0002 0.0002  False
#           Default            Visual      0.0    1.0 -0.0002 0.0002  False
#  Dorsal Attention    Frontoparietal     -0.0 0.9999 -0.0002 0.0002  False
#  Dorsal Attention            Limbic   0.0001 0.8559 -0.0001 0.0003  False
#  Dorsal Attention       Somatomotor  -0.0001 0.9328 -0.0002 0.0001  False
#  Dorsal Attention Ventral Attention  -0.0001 0.7154 -0.0003 0.0001  False
#  Dorsal Attention            Visual  -0.0001 0.8797 -0.0002 0.0001  False
#    Frontoparietal            Limbic   0.0001 0.7252 -0.0001 0.0004  False
#    Frontoparietal       Somatomotor     -0.0 0.9911 -0.0002 0.0001  False
#    Frontoparietal Ventral Attention  -0.0001 0.8798 -0.0003 0.0001  False
#    Frontoparietal            Visual  -0.0001 0.9755 -0.0002 0.0001  False
#            Limbic       Somatomotor  -0.0002 0.2302 -0.0004    0.0  False
#            Limbic Ventral Attention  -0.0002 0.1208 -0.0004    0.0  False
#            Limbic            Visual  -0.0002 0.1799 -0.0004    0.0  False
#       Somatomotor Ventral Attention     -0.0  0.991 -0.0002 0.0001  False
#       Somatomotor            Visual     -0.0    1.0 -0.0001 0.0001  False
# Ventral Attention            Visual      0.0  0.998 -0.0001 0.0002  False
# -------------------------------------------------------------------------
#
#
#  One-Way ANOVA with Yeo network on Full Netmats (Schaefer) results - with FDR correction
#
#
#                sum_sq       df          F  PR(>F)  P_FDR
# C(Yeo_name)  0.096367      6.0  329.99992     0.0    0.0
# Residual     4.365386  89693.0        NaN     NaN    NaN
#
#
#  Post Hoc for Yeo_name - absolute value
#
#
#            Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==========================================================================
#       group1            group2      meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------------------
#           Default  Dorsal Attention   0.0022    0.0  0.0019  0.0025   True
#           Default    Frontoparietal   0.0005    0.0  0.0002  0.0008   True
#           Default            Limbic   0.0003 0.1319    -0.0  0.0006  False
#           Default       Somatomotor   0.0029    0.0  0.0026  0.0031   True
#           Default Ventral Attention   0.0021    0.0  0.0018  0.0024   True
#           Default            Visual   0.0017    0.0  0.0014  0.0019   True
#  Dorsal Attention    Frontoparietal  -0.0017    0.0  -0.002 -0.0014   True
#  Dorsal Attention            Limbic  -0.0019    0.0 -0.0023 -0.0016   True
#  Dorsal Attention       Somatomotor   0.0007    0.0  0.0004  0.0009   True
#  Dorsal Attention Ventral Attention  -0.0001  0.938 -0.0004  0.0002  False
#  Dorsal Attention            Visual  -0.0005    0.0 -0.0008 -0.0003   True
#    Frontoparietal            Limbic  -0.0002 0.5345 -0.0006  0.0001  False
#    Frontoparietal       Somatomotor   0.0024    0.0  0.0021  0.0026   True
#    Frontoparietal Ventral Attention   0.0016    0.0  0.0013  0.0019   True
#    Frontoparietal            Visual   0.0012    0.0  0.0009  0.0014   True
#            Limbic       Somatomotor   0.0026    0.0  0.0023  0.0029   True
#            Limbic Ventral Attention   0.0018    0.0  0.0015  0.0021   True
#            Limbic            Visual   0.0014    0.0  0.0011  0.0017   True
#       Somatomotor Ventral Attention  -0.0008    0.0  -0.001 -0.0005   True
#       Somatomotor            Visual  -0.0012    0.0 -0.0014  -0.001   True
# Ventral Attention            Visual  -0.0004    0.0 -0.0007 -0.0002   True
# --------------------------------------------------------------------------

# %%
### old anovas code


for df in structural_dfs:
    abs_df = df.copy()
    abs_df["estimate"] = abs_df["estimate"].abs()

    #perform three-way ANOVA
    model = ols("""estimate ~ C(phen_group) + C(Yeo_name) + C(phen_group):C(Yeo_name)""", data=abs_df).fit()

    print("\n\n Two-Way ANOVA with Yeo_name and phen_group - absolute value \n\n")
    print((sm.stats.anova_lm(model, typ=2)))

    # post hoc for Yeo_name 
    mc = MultiComparison(abs_df['estimate'], abs_df['Yeo_name'])
    posthoc_results = mc.tukeyhsd()
    print("\n\n Post Hoc for Yeo_name - absolute value \n\n")
    print(posthoc_results)

    # post_hoc for phen_group
    mc = MultiComparison(abs_df['estimate'], abs_df['phen_group'])
    posthoc_results = mc.tukeyhsd()
    print("\n\n Post Hoc for phen_group - absolute value \n\n")
    print(posthoc_results)
    #two way ANOVA with main effect for network and main effect for phenotype group


print("begin functional anovas")
for df in functional_dfs:
    abs_df = df.copy()
    abs_df["estimate"] = abs_df["estimate"].abs()

    #perform three-way ANOVA
    model = ols("""estimate ~ C(phen_group) + C(Yeo_name) + C(phen_group):C(Yeo_name)""", data=abs_df).fit()

    print("\n\n Two-Way ANOVA with Yeo_name and phen_group - absolute value \n\n")
    print((sm.stats.anova_lm(model, typ=2)))

    # post hoc for Yeo_name 
    mc = MultiComparison(abs_df['estimate'], abs_df['Yeo_name'])
    posthoc_results = mc.tukeyhsd()
    print("\n\n Post Hoc for Yeo_name - absolute value \n\n")
    print(posthoc_results)

    # post_hoc for phen_group
    mc = MultiComparison(abs_df['estimate'], abs_df['phen_group'])
    posthoc_results = mc.tukeyhsd()
    print("\n\n Post Hoc for phen_group - absolute value \n\n")
    print(posthoc_results)
    #two way ANOVA with main effect for network and main effect for phenotype group

# %%
### old anovas code


print("ANOVAs on combined meta-analysis results across all imaging metrics")

df_volume["estimate"] = df_volume["estimate"].abs()
df_volume["imaging_metric"] = "volume"
df_area["estimate"] = df_area["estimate"].abs()
df_area["imaging_metric"] = "area" 
df_thickness["estimate"] = df_thickness["estimate"].abs()
df_thickness["imaging_metric"] = "thickness"
amp_df["estimate"] = amp_df["estimate"].abs()
amp_df["imaging_metric"] = "amplitude"
fc_df["estimate"] = fc_df["estimate"].abs()
fc_df["imaging_metric"] = "partial netmats"

df_total = pd.concat([df_volume, df_area, df_thickness, amp_df, fc_df], ignore_index=True)
# print(df_total.columns)

# perform three-way ANOVA
model = ols("""estimate ~ C(phen_group) + C(Yeo_name) + C(imaging_metric) +
            C(phen_group):C(Yeo_name) + C(phen_group):C(imaging_metric) + C(Yeo_name):C(imaging_metric)""", data=df_total).fit()
print("\n\n Three-Way ANOVA with Yeo_name phen_group and image data type (absolute value) \n\n")
print((sm.stats.anova_lm(model, typ=2)))

# post hoc for Yeo_name 
mc = MultiComparison(df_total['estimate'], df_total['Yeo_name'])
posthoc_results = mc.tukeyhsd()
print("\n\n Post Hoc for Yeo_name - absolute value \n\n")
print(posthoc_results)

# post_hoc for phen_group
mc = MultiComparison(df_total['estimate'], df_total['phen_group'])
posthoc_results = mc.tukeyhsd()
print("\n\n Post Hoc for phen_group - absolute value \n\n")
print(posthoc_results)

# post_hoc for brain data type
mc = MultiComparison(df_total['estimate'], df_total['imaging_metric'])
posthoc_results = mc.tukeyhsd()
print("\n\n Post Hoc for imaging metric (absolute val) \n\n")
print(posthoc_results)
